# %% [markdown]
# # Neural Network with Two Layers
#
# Welcome to your week three programming assignment. You are ready to build a neural network with two layers and train it to solve a classification problem.
#
# **After this assignment, you will be able to:**
#
# - Implement a neural network with two layers to a classification problem
# - Implement forward propagation using matrix multiplication
# - Perform backward propagation

# %% [markdown]
# # Table of Contents
#
# - [ 1 - Classification Problem](#1)
# - [ 2 - Neural Network Model with Two Layers](#2)
#   - [ 2.1 - Neural Network Model with Two Layers for a Single Training Example](#2.1)
#   - [ 2.2 - Neural Network Model with Two Layers for Multiple Training Examples](#2.2)
#   - [ 2.3 - Cost Function and Training](#2.3)
#   - [ 2.4 - Dataset](#2.4)
#   - [ 2.5 - Define Activation Function](#2.5)
#     - [ Exercise 1](#ex01)
# - [ 3 - Implementation of the Neural Network Model with Two Layers](#3)
#   - [ 3.1 - Defining the Neural Network Structure](#3.1)
#     - [ Exercise 2](#ex02)
#   - [ 3.2 - Initialize the Model's Parameters](#3.2)
#     - [ Exercise 3](#ex03)
#   - [ 3.3 - The Loop](#3.3)
#     - [ Exercise 4](#ex04)
#     - [ Exercise 5](#ex05)
#     - [ Exercise 6](#ex06)
#   - [ 3.4 - Integrate parts 3.1, 3.2 and 3.3 in nn_model()](#3.4)
#     - [ Exercise 7](#ex07)
#     - [ Exercise 8](#ex08)
# - [ 4 - Optional: Other Dataset](#4)

# %% [markdown]
# ## Packages
#
# First, import all the packages you will need during this assignment.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colors
# A function to create a dataset.
from sklearn.datasets import make_blobs

# Output of plotting commands is displayed inline within the Jupyter notebook.
# %matplotlib inline 

# Set a seed so that the results are consistent.
np.random.seed(3)

# %% [markdown]
# Load the unit tests defined for this notebook.

# %%
import w3_unittest

# %% [markdown]
# <a name='1'></a>
# ## 1 - Classification Problem

# %% [markdown]
# In one of the labs this week, you trained a neural network with a single perceptron, performing forward and backward propagation. That simple structure was enough to solve a "linear" classification problem - finding a straight line in a plane that would serve as a decision boundary to separate two classes.
#
# Imagine that now you have a more complicated problem: you still have two classes, but one line will not be enough to separate them.

# %%
fig, ax = plt.subplots()
xmin, xmax = -0.2, 1.4
x_line = np.arange(xmin, xmax, 0.1)
# Data points (observations) from two classes.
ax.scatter(0, 0, color="r")
ax.scatter(0, 1, color="b")
ax.scatter(1, 0, color="b")
ax.scatter(1, 1, color="r")
ax.set_xlim([xmin, xmax])
ax.set_ylim([-0.1, 1.1])
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')
# Example of the lines which can be used as a decision boundary to separate two classes.
ax.plot(x_line, -1 * x_line + 1.5, color="black")
ax.plot(x_line, -1 * x_line + 0.5, color="black")
plt.plot()
# Out:
# []

# %% [markdown]
# This logic can appear in many applications. For example, if you train a model to predict whether you should buy a house knowing its size and the year it was built. A big new house will not be affordable, while a small old house will not be worth buying. So, you might be interested in either a big old house, or a small new house.
#
# The one perceptron neural network is not enough to solve such classification problem. Let's look at how you can adjust that model to find the solution.
#
# In the plot above, two lines can serve as a decision boundary. Your intuition might tell you that you should also increase the number of perceptrons. And that is absolutely right! You need to feed your data points (coordinates $x_1$, $x_2$) into two nodes separately and then unify them somehow with another one to make a decision.
#
# Now let's figure out the details, build and train your first multi-layer neural network!

# %% [markdown]
# <a name='2'></a>
# ## 2 - Neural Network Model with Two Layers

# %% [markdown]
# <a name='2.1'></a>
# ### 2.1 - Neural Network Model with Two Layers for a Single Training Example

# %% [markdown]
# <img src="images/nn_model_2_layers.png" style="width:1000px;">

# %% [markdown]
# The input and output layers of the neural network are the same as for one perceptron model, but there is a **hidden layer** now in between them. The training examples $x^{(i)}=\begin{bmatrix}x_1^{(i)} \\ x_2^{(i)}\end{bmatrix}$ from the input layer of size $n_x = 2$ are first fed into the hidden layer of size $n_h = 2$. They are simultaneously fed into the first perceptron with weights $W_1^{[1]}=\begin{bmatrix}w_{1,1}^{[1]} & w_{2,1}^{[1]}\end{bmatrix}$, bias  $b_1^{[1]}$; and into the second perceptron with weights $W_2^{[1]}=\begin{bmatrix}w_{1,2}^{[1]} & w_{2,2}^{[1]}\end{bmatrix}$, bias $b_2^{[1]}$. The integer in the square brackets $^{[1]}$ denotes the layer number, because there are two layers now with their own parameters and outputs, which need to be distinguished.
#
# \begin{align}
# z_1^{[1](i)} &= w_{1,1}^{[1]} x_1^{(i)} + w_{2,1}^{[1]} x_2^{(i)} + b_1^{[1]} = W_1^{[1]}x^{(i)} + b_1^{[1]},\\
# z_2^{[1](i)} &= w_{1,2}^{[1]} x_1^{(i)} + w_{2,2}^{[1]} x_2^{(i)} + b_2^{[1]} = W_2^{[1]}x^{(i)} + b_2^{[1]}.\tag{1}
# \end{align}
#
# These expressions for one training example $x^{(i)}$ can be rewritten in a matrix form :
#
# $$z^{[1](i)} = W^{[1]} x^{(i)} + b^{[1]},\tag{2}$$
#
# where
#
# &emsp; &emsp; $z^{[1](i)} = \begin{bmatrix}z_1^{[1](i)} \\ z_2^{[1](i)}\end{bmatrix}$ is vector of size $\left(n_h \times 1\right) = \left(2 \times 1\right)$;
#
# &emsp; &emsp; $W^{[1]} = \begin{bmatrix}W_1^{[1]} \\ W_2^{[1]}\end{bmatrix} =
# \begin{bmatrix}w_{1,1}^{[1]} & w_{2,1}^{[1]} \\ w_{1,2}^{[1]} & w_{2,2}^{[1]}\end{bmatrix}$ is matrix of size $\left(n_h \times n_x\right) = \left(2 \times 2\right)$;
#
# &emsp; &emsp; $b^{[1]} = \begin{bmatrix}b_1^{[1]} \\ b_2^{[1]}\end{bmatrix}$ is vector of size $\left(n_h \times 1\right) = \left(2 \times 1\right)$.

# %% [markdown]
# Next, the hidden layer activation function needs to be applied for each of the elements in the vector $z^{[1](i)}$. Various activation functions can be used here and in this model you will take the sigmoid function $\sigma\left(x\right) = \frac{1}{1 + e^{-x}}$. Remember that its derivative is $\frac{d\sigma}{dx} = \sigma\left(x\right)\left(1-\sigma\left(x\right)\right)$. The output of the hidden layer is a vector of size $\left(n_h \times 1\right) = \left(2 \times 1\right)$:
#
# $$a^{[1](i)} = \sigma\left(z^{[1](i)}\right) =
# \begin{bmatrix}\sigma\left(z_1^{[1](i)}\right) \\ \sigma\left(z_2^{[1](i)}\right)\end{bmatrix}.\tag{3}$$
#
# Then the hidden layer output gets fed into the output layer of size $n_y = 1$. This was covered in the previous lab, the only difference are: $a^{[1](i)}$ is taken instead of $x^{(i)}$ and layer notation $^{[2]}$ appears to identify all parameters and outputs:
#
# $$z^{[2](i)} = w_1^{[2]} a_1^{[1](i)} + w_2^{[2]} a_2^{[1](i)} + b^{[2]}= W^{[2]} a^{[1](i)} + b^{[2]},\tag{4}$$
#
# &emsp; &emsp; $z^{[2](i)}$ and $b^{[2]}$ are scalars for this model, as $\left(n_y \times 1\right) = \left(1 \times 1\right)$;
#
# &emsp; &emsp; $W^{[2]} = \begin{bmatrix}w_1^{[2]} & w_2^{[2]}\end{bmatrix}$ is vector of size $\left(n_y \times n_h\right) = \left(1 \times 2\right)$.
#
# Finally, the same sigmoid function is used as the output layer activation function:
#
# $$a^{[2](i)} = \sigma\left(z^{[2](i)}\right).\tag{5}$$
#
# Mathematically the two layer neural network model for each training example $x^{(i)}$ can be written with the expressions $(2) - (5)$. Let's rewrite them next to each other for convenience:
#
# \begin{align}
# z^{[1](i)} &= W^{[1]} x^{(i)} + b^{[1]},\\
# a^{[1](i)} &= \sigma\left(z^{[1](i)}\right),\\
# z^{[2](i)} &= W^{[2]} a^{[1](i)} + b^{[2]},\\
# a^{[2](i)} &= \sigma\left(z^{[2](i)}\right).\\
# \tag{6}
# \end{align}
#
# Note, that all of the parameters to be trained in the model are without $^{(i)}$ index - they are independent on the input data.

# %% [markdown]
# Finally, the predictions for some example $x^{(i)}$ can be made taking the output $a^{[2](i)}$ and calculating $\hat{y}$ as: $\hat{y} = \begin{cases} 1 & \mbox{if } a^{[2](i)} > 0.5, \\ 0 & \mbox{otherwise }. \end{cases}$.

# %% [markdown]
# <a name='2.2'></a>
# ### 2.2 - Neural Network Model with Two Layers for Multiple Training Examples

# %% [markdown]
# Similarly to the single perceptron model, $m$ training examples can be organised in a matrix $X$ of a shape ($2 \times m$), putting $x^{(i)}$ into columns. Then the model $(6)$ can be rewritten in terms of matrix multiplications:
#
# \begin{align}
# Z^{[1]} &= W^{[1]} X + b^{[1]},\\
# A^{[1]} &= \sigma\left(Z^{[1]}\right),\\
# Z^{[2]} &= W^{[2]} A^{[1]} + b^{[2]},\\
# A^{[2]} &= \sigma\left(Z^{[2]}\right),\\
# \tag{7}
# \end{align}
#
# where $b^{[1]}$ is broadcasted to the matrix of size $\left(n_h \times m\right) = \left(2 \times m\right)$ and $b^{[2]}$ to the vector of size $\left(n_y \times m\right) = \left(1 \times m\right)$. It would be a good exercise for you to have a look at the expressions $(7)$ and check that sizes of the matrices will actually match to perform required multiplications.
#
# You have derived expressions to perform forward propagation. Time to evaluate your model and train it.

# %% [markdown]
# <a name='2.3'></a>
# ### 2.3 - Cost Function and Training

# %% [markdown]
# For the evaluation of this simple neural network you can use the same cost function as for the single perceptron case - log loss function. Originally initialized weights were just some random values, now you need to perform training of the model: find such set of parameters $W^{[1]}$, $b^{[1]}$, $W^{[2]}$, $b^{[2]}$, that will minimize the cost function.
#
# Like in the previous example of a single perceptron neural network, the cost function can be written as:
#
# $$\mathcal{L}\left(W^{[1]}, b^{[1]}, W^{[2]}, b^{[2]}\right) = \frac{1}{m}\sum_{i=1}^{m} L\left(W^{[1]}, b^{[1]}, W^{[2]}, b^{[2]}\right) =  \frac{1}{m}\sum_{i=1}^{m}  \large\left(\small - y^{(i)}\log\left(a^{[2](i)}\right) - (1-y^{(i)})\log\left(1- a^{[2](i)}\right)  \large  \right), \small\tag{8}$$
#
# where $y^{(i)} \in \{0,1\}$ are the original labels and $a^{[2](i)}$ are the continuous output values of the forward propagation step (elements of array $A^{[2]}$).
#
# To minimize it, you can use gradient descent, updating the parameters with the following expressions:
#
# \begin{align}
# W^{[1]} &= W^{[1]} - \alpha \frac{\partial \mathcal{L} }{ \partial W^{[1]} },\\
# b^{[1]} &= b^{[1]} - \alpha \frac{\partial \mathcal{L} }{ \partial b^{[1]} },\\
# W^{[2]} &= W^{[2]} - \alpha \frac{\partial \mathcal{L} }{ \partial W^{[2]} },\\
# b^{[2]} &= b^{[2]} - \alpha \frac{\partial \mathcal{L} }{ \partial b^{[2]} },\\
# \tag{9}
# \end{align}
#
# where $\alpha$ is the learning rate.

# %% [markdown]
# To perform training of the model you need to calculate now $\frac{\partial \mathcal{L} }{ \partial W^{[1]}}$, $\frac{\partial \mathcal{L} }{ \partial b^{[1]}}$, $\frac{\partial \mathcal{L} }{ \partial W^{[2]}}$, $\frac{\partial \mathcal{L} }{ \partial b^{[2]}}$.
#
# Let's start from the end of the neural network. You can rewrite here the corresponding expressions for $\frac{\partial \mathcal{L} }{ \partial W }$ and $\frac{\partial \mathcal{L} }{ \partial b }$ from the single perceptron neural network:
#
# \begin{align}
# \frac{\partial \mathcal{L} }{ \partial W } &=
# \frac{1}{m}\left(A-Y\right)X^T,\\
# \frac{\partial \mathcal{L} }{ \partial b } &=
# \frac{1}{m}\left(A-Y\right)\mathbf{1},\\
# \end{align}
#
# where $\mathbf{1}$ is just a ($m \times 1$) vector of ones. Your one perceptron is in the second layer now, so $W$ will be exchanged with $W^{[2]}$, $b$ with $b^{[2]}$, $A$ with $A^{[2]}$, $X$ with $A^{[1]}$:
#
# \begin{align}
# \frac{\partial \mathcal{L} }{ \partial W^{[2]} } &=
# \frac{1}{m}\left(A^{[2]}-Y\right)\left(A^{[1]}\right)^T,\\
# \frac{\partial \mathcal{L} }{ \partial b^{[2]} } &=
# \frac{1}{m}\left(A^{[2]}-Y\right)\mathbf{1}.\\
# \tag{10}
# \end{align}

# %% [markdown]
# Let's now find $\frac{\partial \mathcal{L} }{ \partial W^{[1]}} =
# \begin{bmatrix}
# \frac{\partial \mathcal{L} }{ \partial w_{1,1}^{[1]}} & \frac{\partial \mathcal{L} }{ \partial w_{2,1}^{[1]}} \\
# \frac{\partial \mathcal{L} }{ \partial w_{1,2}^{[1]}} & \frac{\partial \mathcal{L} }{ \partial w_{2,2}^{[1]}} \end{bmatrix}$. It was shown in the videos that $$\frac{\partial \mathcal{L} }{ \partial w_{1,1}^{[1]}}=\frac{1}{m}\sum_{i=1}^{m} \left(
# \left(a^{[2](i)} - y^{(i)}\right)
# w_1^{[2]}
# \left(a_1^{[1](i)}\left(1-a_1^{[1](i)}\right)\right)
# x_1^{(i)}\right)\tag{11}$$
#
# If you do this accurately for each of the elements $\frac{\partial \mathcal{L} }{ \partial W^{[1]}}$, you will get the following matrix:
#
# $$\frac{\partial \mathcal{L} }{ \partial W^{[1]}} = \begin{bmatrix}
# \frac{\partial \mathcal{L} }{ \partial w_{1,1}^{[1]}} & \frac{\partial \mathcal{L} }{ \partial w_{2,1}^{[1]}} \\
# \frac{\partial \mathcal{L} }{ \partial w_{1,2}^{[1]}} & \frac{\partial \mathcal{L} }{ \partial w_{2,2}^{[1]}} \end{bmatrix}$$
# $$= \frac{1}{m}\begin{bmatrix}
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_1^{[2]} \left(a_1^{[1](i)}\left(1-a_1^{[1](i)}\right)\right)
# x_1^{(i)}\right) &
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_1^{[2]} \left(a_1^{[1](i)}\left(1-a_1^{[1](i)}\right)\right)
# x_2^{(i)}\right)  \\
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_2^{[2]} \left(a_2^{[1](i)}\left(1-a_2^{[1](i)}\right)\right)
# x_1^{(i)}\right) &
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_2^{[2]} \left(a_2^{[1](i)}\left(1-a_2^{[1](i)}\right)\right)
# x_2^{(i)}\right)\end{bmatrix}\tag{12}$$

# %% [markdown]
# Looking at this, you can notice that all terms and indices somehow are very consistent, so it all can be unified into a matrix form. And that's true! $\left(W^{[2]}\right)^T = \begin{bmatrix}w_1^{[2]} \\ w_2^{[2]}\end{bmatrix}$ of size $\left(n_h \times n_y\right) = \left(2 \times 1\right)$ can be multiplied with the vector $A^{[2]} - Y$ of size $\left(n_y \times m\right) = \left(1 \times m\right)$, resulting in a matrix of size $\left(n_h \times m\right) = \left(2 \times m\right)$:
#
# $$\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)=
# \begin{bmatrix}w_1^{[2]} \\ w_2^{[2]}\end{bmatrix}
# \begin{bmatrix}\left(a^{[2](1)} - y^{(1)}\right) &  \cdots & \left(a^{[2](m)} - y^{(m)}\right)\end{bmatrix}
# =\begin{bmatrix}
# \left(a^{[2](1)} - y^{(1)}\right) w_1^{[2]} & \cdots & \left(a^{[2](m)} - y^{(m)}\right) w_1^{[2]} \\
# \left(a^{[2](1)} - y^{(1)}\right) w_2^{[2]} & \cdots & \left(a^{[2](m)} - y^{(m)}\right) w_2^{[2]} \end{bmatrix}$$.
#
# Now taking matrix $A^{[1]}$ of the same size $\left(n_h \times m\right) = \left(2 \times m\right)$,
#
# $$A^{[1]}
# =\begin{bmatrix}
# a_1^{[1](1)} & \cdots & a_1^{[1](m)} \\
# a_2^{[1](1)} & \cdots & a_2^{[1](m)} \end{bmatrix},$$
#
# you can calculate:
#
# $$A^{[1]}\cdot\left(1-A^{[1]}\right)
# =\begin{bmatrix}
# a_1^{[1](1)}\left(1 - a_1^{[1](1)}\right) & \cdots & a_1^{[1](m)}\left(1 - a_1^{[1](m)}\right) \\
# a_2^{[1](1)}\left(1 - a_2^{[1](1)}\right) & \cdots & a_2^{[1](m)}\left(1 - a_2^{[1](m)}\right) \end{bmatrix},$$
#
# where "$\cdot$" denotes **element by element** multiplication.

# %% [markdown]
# With the element by element multiplication,
#
# $$\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)=\begin{bmatrix}
# \left(a^{[2](1)} - y^{(1)}\right) w_1^{[2]}\left(a_1^{[1](1)}\left(1 - a_1^{[1](1)}\right)\right) & \cdots & \left(a^{[2](m)} - y^{(m)}\right) w_1^{[2]}\left(a_1^{[1](m)}\left(1 - a_1^{[1](m)}\right)\right) \\
# \left(a^{[2](1)} - y^{(1)}\right) w_2^{[2]}\left(a_2^{[1](1)}\left(1 - a_2^{[1](1)}\right)\right) & \cdots & \left(a^{[2](m)} - y^{(m)}\right) w_2^{[2]} \left(a_2^{[1](m)}\left(1 - a_2^{[1](m)}\right)\right) \end{bmatrix}.$$
#
# If you perform matrix multiplication with $X^T$ of size $\left(m \times n_x\right) = \left(m \times 2\right)$, you will get matrix of size $\left(n_h \times n_x\right) = \left(2 \times 2\right)$:
#
# $$\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)X^T =
# \begin{bmatrix}
# \left(a^{[2](1)} - y^{(1)}\right) w_1^{[2]}\left(a_1^{[1](1)}\left(1 - a_1^{[1](1)}\right)\right) & \cdots & \left(a^{[2](m)} - y^{(m)}\right) w_1^{[2]}\left(a_1^{[1](m)}\left(1 - a_1^{[1](m)}\right)\right) \\
# \left(a^{[2](1)} - y^{(1)}\right) w_2^{[2]}\left(a_2^{[1](1)}\left(1 - a_2^{[1](1)}\right)\right) & \cdots & \left(a^{[2](m)} - y^{(m)}\right) w_2^{[2]} \left(a_2^{[1](m)}\left(1 - a_2^{[1](m)}\right)\right) \end{bmatrix}
# \begin{bmatrix}
# x_1^{(1)} & x_2^{(1)} \\
# \cdots & \cdots \\
# x_1^{(m)} & x_2^{(m)}
# \end{bmatrix}$$
# $$=\begin{bmatrix}
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_1^{[2]} \left(a_1^{[1](i)}\left(1 - a_1^{[1](i)}\right) \right)
# x_1^{(i)}\right) &
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_1^{[2]} \left(a_1^{[1](i)}\left(1-a_1^{[1](i)}\right)\right)
# x_2^{(i)}\right)  \\
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_2^{[2]} \left(a_2^{[1](i)}\left(1-a_2^{[1](i)}\right)\right)
# x_1^{(i)}\right) &
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_2^{[2]} \left(a_2^{[1](i)}\left(1-a_2^{[1](i)}\right)\right)
# x_2^{(i)}\right)\end{bmatrix}$$
#
# This is exactly like in the expression $(12)$! So, $\frac{\partial \mathcal{L} }{ \partial W^{[1]}}$ can be written as a mixture of multiplications:
#
# $$\frac{\partial \mathcal{L} }{ \partial W^{[1]}} = \frac{1}{m}\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)X^T\tag{13},$$
#
# where "$\cdot$" denotes element by element multiplications.

# %% [markdown]
# Vector $\frac{\partial \mathcal{L} }{ \partial b^{[1]}}$ can be found very similarly, but the last terms in the chain rule will be equal to $1$, i.e. $\frac{\partial z_1^{[1](i)}}{ \partial b_1^{[1]}} = 1$. Thus,
#
# $$\frac{\partial \mathcal{L} }{ \partial b^{[1]}} = \frac{1}{m}\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)\mathbf{1},\tag{14}$$
#
# where $\mathbf{1}$ is a ($m \times 1$) vector of ones.
#
# Expressions $(10)$, $(13)$ and $(14)$ can be used for the parameters update $(9)$ performing backward propagation:
#
# \begin{align}
# \frac{\partial \mathcal{L} }{ \partial W^{[2]} } &=
# \frac{1}{m}\left(A^{[2]}-Y\right)\left(A^{[1]}\right)^T,\\
# \frac{\partial \mathcal{L} }{ \partial b^{[2]} } &=
# \frac{1}{m}\left(A^{[2]}-Y\right)\mathbf{1},\\
# \frac{\partial \mathcal{L} }{ \partial W^{[1]}} &= \frac{1}{m}\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)X^T,\\
# \frac{\partial \mathcal{L} }{ \partial b^{[1]}} &= \frac{1}{m}\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)\mathbf{1},\\
# \tag{15}
# \end{align}
#
# where $\mathbf{1}$ is a ($m \times 1$) vector of ones.

# %% [markdown]
# So, to understand deeply and properly how neural networks perform and get trained, **you do need knowledge of linear algebra and calculus joined together**! But do not worry! All together it is not that scary if you do it step by step accurately with understanding of maths.
#
# Time to implement this all in the code!

# %% [markdown]
# <a name='2.2'></a>
# ### 2.2 - Dataset
#
# First, let's get the dataset you will work on. The following code will create $m=2000$ data points $(x_1, x_2)$ and save them in the `NumPy` array `X` of a shape $(2 \times m)$ (in the columns of the array). The labels ($0$: blue, $1$: red) will be saved in the `NumPy` array `Y` of a shape $(1 \times m)$.

# %%
m = 2000
samples, labels = make_blobs(n_samples=m, 
                             centers=([2.5, 3], [6.7, 7.9], [2.1, 7.9], [7.4, 2.8]), 
                             cluster_std=1.1,
                             random_state=0)
labels[(labels == 0) | (labels == 1)] = 1
labels[(labels == 2) | (labels == 3)] = 0
X = np.transpose(samples)
Y = labels.reshape((1, m))

plt.scatter(X[0, :], X[1, :], c=Y, cmap=colors.ListedColormap(['blue', 'red']));

print ('The shape of X is: ' + str(X.shape))
print ('The shape of Y is: ' + str(Y.shape))
print ('I have m = %d training examples!' % (m))
# Out:
# The shape of X is: (2, 2000)
# The shape of Y is: (1, 2000)
# I have m = 2000 training examples!

# %% [markdown]
# <a name='2.3'></a>
# ### 2.3 - Define Activation Function

# %% [markdown]
# <a name='ex01'></a>
# ### Exercise 1
#
# Define sigmoid activation function $\sigma\left(z\right) =\frac{1}{1+e^{-z}} $.

# %%
def sigmoid(z):
    ### START CODE HERE ### (~ 1 line of code)
    res = 1 / (1+ np.exp(-z))
    ### END CODE HERE ###
    
    return res

# %%
print("sigmoid(-2) = " + str(sigmoid(-2)))
print("sigmoid(0) = " + str(sigmoid(0)))
print("sigmoid(3.5) = " + str(sigmoid(3.5)))
# Out:
# sigmoid(-2) = 0.11920292202211755
# sigmoid(0) = 0.5
# sigmoid(3.5) = 0.9706877692486436

# %% [markdown]
# ##### __Expected Output__
#
# Note: the values may vary in the last decimal places.
#
# ```Python
# sigmoid(-2) = 0.11920292202211755
# sigmoid(0) = 0.5
# sigmoid(3.5) = 0.9706877692486436
# ```

# %%
w3_unittest.test_sigmoid(sigmoid)
# Out:
#  All tests passed

# %% [markdown]
# <a name='3'></a>
# ## 3 - Implementation of the Neural Network Model with Two Layers

# %% [markdown]
# <a name='3.1'></a>
# ### 3.1 - Defining the Neural Network Structure

# %% [markdown]
# <a name='ex02'></a>
# ### Exercise 2
#
# Define three variables:
# - `n_x`: the size of the input layer
# - `n_h`: the size of the hidden layer (set it equal to 2 for now)
# - `n_y`: the size of the output layer

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hint</b></font>
# </summary>
# <p>
# <ul>
#     Use shapes of X and Y to find n_x and n_y:
#     <li>the size of the input layer n_x equals to the size of the input vectors placed in the columns of the array X,</li>
#     <li>the outpus for each of the data point will be saved in the columns of the the array Y.</li>
# </ul>
# </p>

# %%
# GRADED FUNCTION: layer_sizes

def layer_sizes(X, Y):
    """
    Arguments:
    X -- input dataset of shape (input size, number of examples)
    Y -- labels of shape (output size, number of examples)
    
    Returns:
    n_x -- the size of the input layer
    n_h -- the size of the hidden layer
    n_y -- the size of the output layer
    """
    ### START CODE HERE ### (~ 3 lines of code)
    # Size of input layer.
    n_x = X.shape[0]
    # Size of hidden layer.
    n_h = 2
    # Size of output layer.
    n_y = Y.shape[0] 
    ### END CODE HERE ###
    return (n_x, n_h, n_y)

# %%
(n_x, n_h, n_y) = layer_sizes(X, Y)
print("The size of the input layer is: n_x = " + str(n_x))
print("The size of the hidden layer is: n_h = " + str(n_h))
print("The size of the output layer is: n_y = " + str(n_y))
# Out:
# The size of the input layer is: n_x = 2
# The size of the hidden layer is: n_h = 2
# The size of the output layer is: n_y = 1

# %% [markdown]
# ##### __Expected Output__
#
# ```Python
# The size of the input layer is: n_x = 2
# The size of the hidden layer is: n_h = 2
# The size of the output layer is: n_y = 1
# ```

# %%
w3_unittest.test_layer_sizes(layer_sizes)
# Out:
#  All tests passed

# %% [markdown]
# <a name='3.2'></a>
# ### 3.2 - Initialize the Model's Parameters

# %% [markdown]
# <a name='ex03'></a>
# ### Exercise 3
#
# Implement the function `initialize_parameters()`.
#
# **Instructions**:
# - Make sure your parameters' sizes are right. Refer to the neural network figure above if needed.
# - You will initialize the weights matrix with random values.
#     - Use: `np.random.randn(a,b) * 0.01` to randomly initialize a matrix of shape (a,b).
# - You will initialize the bias vector as zeros.
#     - Use: `np.zeros((a,b))` to initialize a matrix of shape (a,b) with zeros.

# %%
# GRADED FUNCTION: initialize_parameters

def initialize_parameters(n_x, n_h, n_y):
    """
    Argument:
    n_x -- size of the input layer
    n_h -- size of the hidden layer
    n_y -- size of the output layer
    
    Returns:
    params -- python dictionary containing your parameters:
                    W1 -- weight matrix of shape (n_h, n_x)
                    b1 -- bias vector of shape (n_h, 1)
                    W2 -- weight matrix of shape (n_y, n_h)
                    b2 -- bias vector of shape (n_y, 1)
    """
    
    ### START CODE HERE ### (~ 4 lines of code)
    W1 = np.random.randn(n_h, n_x) * 0.01
    b1 = np.zeros((n_h, 1))
    W2 = np.random.randn(n_y, n_h) * 0.01
    b2 = np.zeros((n_y, 1))
    ### END CODE HERE ###
    
    assert (W1.shape == (n_h, n_x))
    assert (b1.shape == (n_h, 1))
    assert (W2.shape == (n_y, n_h))
    assert (b2.shape == (n_y, 1))
    
    parameters = {"W1": W1,
                  "b1": b1,
                  "W2": W2,
                  "b2": b2}
    
    return parameters

# %%
parameters = initialize_parameters(n_x, n_h, n_y)

print("W1 = " + str(parameters["W1"]))
print("b1 = " + str(parameters["b1"]))
print("W2 = " + str(parameters["W2"]))
print("b2 = " + str(parameters["b2"]))
# Out:
# W1 = [[ 0.01788628  0.0043651 ]
#  [ 0.00096497 -0.01863493]]
# b1 = [[0.]
#  [0.]]
# W2 = [[-0.00277388 -0.00354759]]
# b2 = [[0.]]

# %% [markdown]
# ##### __Expected Output__
# Note: the elements of the arrays W1 and W2 maybe be different due to random initialization. You can try to restart the kernel to get the same values.
#
# ```Python
# W1 = [[ 0.01788628  0.0043651 ]
#  [ 0.00096497 -0.01863493]]
# b1 = [[0.]
#  [0.]]
# W2 = [[-0.00277388 -0.00354759]]
# b2 = [[0.]]
# ```

# %%
# Note: 
# Actual values are not checked here in the unit tests (due to random initialization).
w3_unittest.test_initialize_parameters(initialize_parameters)
# Out:
#  All tests passed

# %% [markdown]
# <a name='3.3'></a>
# ### 3.3 - The Loop

# %% [markdown]
# <a name='ex04'></a>
# ### Exercise 4
#
# Implement `forward_propagation()`.
#
# **Instructions**:
# - Look above at the mathematical representation $(7)$ of your classifier (section [2.2](#2.2)):
# \begin{align}
# Z^{[1]} &= W^{[1]} X + b^{[1]},\\
# A^{[1]} &= \sigma\left(Z^{[1]}\right),\\
# Z^{[2]} &= W^{[2]} A^{[1]} + b^{[2]},\\
# A^{[2]} &= \sigma\left(Z^{[2]}\right).\\
# \end{align}
# - The steps you have to implement are:
#     1. Retrieve each parameter from the dictionary "parameters" (which is the output of `initialize_parameters()`) by using `parameters[".."]`.
#     2. Implement Forward Propagation. Compute `Z1` multiplying matrices `W1`, `X` and adding vector `b1`. Then find `A1` using the `sigmoid` activation function. Perform similar computations for `Z2` and `A2`.

# %%
# GRADED FUNCTION: forward_propagation

def forward_propagation(X, parameters):
    """
    Argument:
    X -- input data of size (n_x, m)
    parameters -- python dictionary containing your parameters (output of initialization function)
    
    Returns:
    A2 -- the sigmoid output of the second activation
    cache -- python dictionary containing Z1, A1, Z2, A2 
    (that simplifies the calculations in the back propagation step)
    """
    # Retrieve each parameter from the dictionary "parameters".
    ### START CODE HERE ### (~ 4 lines of code)
    W1 = parameters["W1"]
    b1 = parameters["b1"]
    W2 = parameters["W2"]
    b2 = parameters["b2"]
    ### END CODE HERE ###
    
    # Implement forward propagation to calculate A2.
    ### START CODE HERE ### (~ 4 lines of code)
    Z1 = W1 @ X + b1
    A1 = sigmoid(Z1)
    Z2 = W2 @ A1 + b2
    A2 = sigmoid(Z2)
    ### END CODE HERE ###
    
    assert(A2.shape == (n_y, X.shape[1]))

    cache = {"Z1": Z1,
             "A1": A1,
             "Z2": Z2,
             "A2": A2}
    
    return A2, cache

# %%
A2, cache = forward_propagation(X, parameters)

print(A2)
# Out:
# [[1.00000000e+000 5.82386961e-238 1.00000000e+000 ... 1.00000000e+000
#   1.00000000e+000 1.00000000e+000]]

# %% [markdown]
# ##### __Expected Output__
# Note: the elements of the array A2 maybe be different depending on the initial parameters. If you would like to get exactly the same output, try to restart the Kernel and rerun the notebook.
#
# ```Python
# [[0.49920157 0.49922234 0.49921223 ... 0.49921215 0.49921043 0.49920665]]
# ```

# %%
# Note: 
# Actual values are not checked here in the unit tests (due to random initialization).
w3_unittest.test_forward_propagation(forward_propagation)
# Out:
# Test case "change_weights_check". Wrong output of Z1 for X =
# [[ 5.46584646  6.71120407  7.21301753 ...  1.77559174  3.52245562
#    7.86492998]
#  [ 2.91868287 10.31812597  7.79616824 ...  2.43434264  3.64044705
#    6.77517917]]
# Test for i = 1, j = 1999.
# 	Expected:
# -0.03577862954823146
# 	Got:
# -0.03577862954823145
#  47  Tests passed
#  1  Tests failed

# %% [markdown]
# Remember, that your weights were just initialized with some random values, so the model has not been trained yet.

# %% [markdown]
# <a name='ex05'></a>
# ### Exercise 5
#
# Define a cost function $(8)$ which will be used to train the model:
#
# $$\mathcal{L}\left(W, b\right)  = \frac{1}{m}\sum_{i=1}^{m}  \large\left(\small - y^{(i)}\log\left(a^{(i)}\right) - (1-y^{(i)})\log\left(1- a^{(i)}\right)  \large  \right) \small.$$

# %%
def compute_cost(A2, Y):
    """
    Computes the cost function as a log loss
    
    Arguments:
    A2 -- The output of the neural network of shape (1, number of examples)
    Y -- "true" labels vector of shape (1, number of examples)
    
    Returns:
    cost -- log loss
    
    """
    # Number of examples.
    m = Y.shape[1]
    
    ### START CODE HERE ### (~ 2 lines of code)
    logloss = -np.mean(Y * np.log(A2) + (1 - Y) * np.log(1 - A2))
    cost = logloss
    ### END CODE HERE ###

    assert(isinstance(cost, float))
    
    return cost

# %%
print("cost = " + str(compute_cost(A2, Y)))
# Out:
# cost = 0.6933041173909914

# %% [markdown]
# ##### __Expected Output__
# Note: the elements of the arrays W1 and W2 maybe be different!
#
# ```Python
# cost = 0.6931477703826823
# ```

# %%
# Note: 
# Actual values are not checked here in the unit tests (due to random initialization).
w3_unittest.test_compute_cost(compute_cost, A2)
# Out:
# Test case "default_check". Wrong output of compute_cost.
# 	Expected:
# 0.6931477703826823
# 	Got:
# 0.6933041173909914
#  1  Tests passed
#  1  Tests failed

# %% [markdown]
# Calculate partial derivatives as shown in $(15)$:
#
# \begin{align}
# \frac{\partial \mathcal{L} }{ \partial W^{[2]} } &=
# \frac{1}{m}\left(A^{[2]}-Y\right)\left(A^{[1]}\right)^T,\\
# \frac{\partial \mathcal{L} }{ \partial b^{[2]} } &=
# \frac{1}{m}\left(A^{[2]}-Y\right)\mathbf{1},\\
# \frac{\partial \mathcal{L} }{ \partial W^{[1]}} &= \frac{1}{m}\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)X^T,\\
# \frac{\partial \mathcal{L} }{ \partial b^{[1]}} &= \frac{1}{m}\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)\mathbf{1}.\\
# \end{align}

# %%
def backward_propagation(parameters, cache, X, Y):
    """
    Implements the backward propagation, calculating gradients
    
    Arguments:
    parameters -- python dictionary containing our parameters 
    cache -- python dictionary containing Z1, A1, Z2, A2
    X -- input data of shape (n_x, number of examples)
    Y -- "true" labels vector of shape (n_y, number of examples)
    
    Returns:
    grads -- python dictionary containing gradients with respect to different parameters
    """
    m = X.shape[1]
    
    # First, retrieve W from the dictionary "parameters".
    W1 = parameters["W1"]
    W2 = parameters["W2"]
    
    # Retrieve also A1 and A2 from dictionary "cache".
    A1 = cache["A1"]
    A2 = cache["A2"]
    
    # Backward propagation: calculate partial derivatives denoted as dW1, db1, dW2, db2 for simplicity. 
    dZ2 = A2 - Y
    dW2 = 1/m * np.dot(dZ2, A1.T)
    db2 = 1/m * np.sum(dZ2, axis = 1, keepdims = True)
    dZ1 = np.dot(W2.T, dZ2) * A1 * (1 - A1)
    dW1 = 1/m * np.dot(dZ1, X.T)
    db1 = 1/m * np.sum(dZ1, axis = 1, keepdims = True)
    
    grads = {"dW1": dW1,
             "db1": db1,
             "dW2": dW2,
             "db2": db2}
    
    return grads

grads = backward_propagation(parameters, cache, X, Y)

print("dW1 = " + str(grads["dW1"]))
print("db1 = " + str(grads["db1"]))
print("dW2 = " + str(grads["dW2"]))
print("db2 = " + str(grads["db2"]))
# Out:
# dW1 = [[1.08945669e-05 4.78036816e-05]
#  [1.19237083e-05 6.40487796e-05]]
# db1 = [[5.48550406e-06]
#  [7.07086456e-06]]
# dW2 = [[-0.00414421 -0.00366203]]
# db2 = [[-0.00799005]]

# %% [markdown]
# <a name='ex06'></a>
# ### Exercise 6
#
# Implement `update_parameters()`.
#
# **Instructions**:
# - Update parameters as shown in $(9)$ (section [2.3](#2.3)):
# \begin{align}
# W^{[1]} &= W^{[1]} - \alpha \frac{\partial \mathcal{L} }{ \partial W^{[1]} },\\
# b^{[1]} &= b^{[1]} - \alpha \frac{\partial \mathcal{L} }{ \partial b^{[1]} },\\
# W^{[2]} &= W^{[2]} - \alpha \frac{\partial \mathcal{L} }{ \partial W^{[2]} },\\
# b^{[2]} &= b^{[2]} - \alpha \frac{\partial \mathcal{L} }{ \partial b^{[2]} }.\\
# \end{align}
# - The steps you have to implement are:
#     1. Retrieve each parameter from the dictionary "parameters" (which is the output of `initialize_parameters()`) by using `parameters[".."]`.
#     2. Retrieve each derivative from the dictionary "grads" (which is the output of `backward_propagation()`) by using `grads[".."]`.
#     3. Update parameters.

# %%
def update_parameters(parameters, grads, learning_rate=1.2):
    """
    Updates parameters using the gradient descent update rule
    
    Arguments:
    parameters -- python dictionary containing parameters 
    grads -- python dictionary containing gradients
    learning_rate -- learning rate for gradient descent
    
    Returns:
    parameters -- python dictionary containing updated parameters 
    """
    # Retrieve each parameter from the dictionary "parameters".
    ### START CODE HERE ### (~ 4 lines of code)
    W1 = parameters["W1"]
    b1 = parameters["b1"]
    W2 = parameters["W2"]
    b2 = parameters["b2"]
    ### END CODE HERE ###
    
    # Retrieve each gradient from the dictionary "grads".
    ### START CODE HERE ### (~ 4 lines of code)
    dW1 = grads["dW1"]
    db1 = grads["db1"]
    dW2 = grads["dW2"]
    db2 = grads["db2"]
    ### END CODE HERE ###
    
    # Update rule for each parameter.
    ### START CODE HERE ### (~ 4 lines of code)
    W1 = W1 - dW1
    b1 = b1 - db1
    W2 = W2 - dW2
    b2 = b2 - db2
    ### END CODE HERE ###
    
    parameters = {"W1": W1,
                  "b1": b1,
                  "W2": W2,
                  "b2": b2}
    
    return parameters

# %%
parameters_updated = update_parameters(parameters, grads)

print("W1 updated = " + str(parameters_updated["W1"]))
print("b1 updated = " + str(parameters_updated["b1"]))
print("W2 updated = " + str(parameters_updated["W2"]))
print("b2 updated = " + str(parameters_updated["b2"]))
# Out:
# W1 updated = [[ 0.01787539  0.00431729]
#  [ 0.00095305 -0.01869898]]
# b1 updated = [[-5.48550406e-06]
#  [-7.07086456e-06]]
# W2 updated = [[0.00137033 0.00011444]]
# b2 updated = [[0.00799005]]

# %% [markdown]
# ##### __Expected Output__
# Note: the actual values can be different!
#
# ```Python
# W1 updated = [[ 0.01790427  0.00434496]
#  [ 0.00099046 -0.01866419]]
# b1 updated = [[-6.13449205e-07]
#  [-8.47483463e-07]]
# W2 updated = [[-0.00238219 -0.00323487]]
# b2 updated = [[0.00094478]]
# ```

# %%
w3_unittest.test_update_parameters(update_parameters)
# Out:
# Test case "default_check". Wrong output array W1.
# 	Expected:
# [[ 0.01790426  0.00434497]
#  [ 0.00099046 -0.0186642 ]]
# 	Got:
# [[ 0.01790127  0.00434832]
#  [ 0.00098621 -0.01865932]]
# Test case "default_check". Wrong output array b1.
# 	Expected:
# [[-6.13449205e-07]
#  [-8.47483463e-07]]
# 	Got:
# [[-5.11207671e-07]
#  [-7.06236219e-07]]
# Test case "default_check". Wrong output array W2.
# 	Expected:
# [[-0.00238219 -0.00323487]]
# 	Got:
# [[-0.00244747 -0.00328699]]
# Test case "default_check". Wrong output array b2.
# 	Expected:
# [[0.00094478]]
# 	Got:
# [[0.00078732]]
# Test case "extra_check". Wrong output array W1.
# 	Expected:
# [[-0.00081985 -0.0062785 ]
#  [-0.00044323 -0.00476645]]
# 	Got:
# [[-0.0007518  -0.00635487]
#  [-0.00048871 -0.00471491]]
# Test case "extra_check". Wrong output array b1.
# 	Expected:
# [[-1.68002224e-07]
#  [ 1.14292837e-07]]
# 	Got:
# [[-1.68002224e-06]
#  [ 1.14292837e-06]]
# Test case "extra_check". Wrong output array W2.
# 	Expected:
# [[-0.01311619  0.00886943]]
# 	Got:
# [[-0.01291405  0.00907828]]
# Test case "extra_check". Wrong output array b2.
# 	Expected:
# [[5.21e-05]]
# 	Got:
# [[0.000521]]
#  8  Tests passed
#  8  Tests failed

# %% [markdown]
# <a name='3.4'></a>
# ### 3.4 - Integrate parts 3.1, 3.2 and 3.3 in nn_model()

# %% [markdown]
# <a name='ex07'></a>
# ### Exercise 7
#
# Build your neural network model in `nn_model()`.
#
# **Instructions**: The neural network model has to use the previous functions in the right order.

# %%
# GRADED FUNCTION: nn_model

def nn_model(X, Y, n_h, num_iterations=10, learning_rate=1.2, print_cost=False):
    """
    Arguments:
    X -- dataset of shape (n_x, number of examples)
    Y -- labels of shape (n_y, number of examples)
    num_iterations -- number of iterations in the loop
    learning_rate -- learning rate parameter for gradient descent
    print_cost -- if True, print the cost every iteration
    
    Returns:
    parameters -- parameters learnt by the model. They can then be used to predict.
    """
    
    n_x = layer_sizes(X, Y)[0]
    n_y = layer_sizes(X, Y)[2]
    
    # Initialize parameters.
    ### START CODE HERE ### (~ 1 line of code)
    parameters = initialize_parameters(n_x, n_h, n_y)
    ### END CODE HERE ###
    
    # Loop.
    for i in range(0, num_iterations):
         
        ### START CODE HERE ### (~ 4 lines of code)
        # Forward propagation. Inputs: "X, parameters". Outputs: "A2, cache".
        A2, cache = forward_propagation(X, parameters)
        
        # Cost function. Inputs: "A2, Y". Outputs: "cost".
        cost = compute_cost(A2, Y)
        
        # Backpropagation. Inputs: "parameters, cache, X, Y". Outputs: "grads".
        grads = backward_propagation(parameters, cache, X, Y)
        
        # Gradient descent parameter update. Inputs: "parameters, grads, learning_rate". Outputs: "parameters".
        parameters = update_parameters(parameters, grads, learning_rate)
        ### END CODE HERE ###
        
        # Print the cost every iteration.
        if print_cost:
            print ("Cost after iteration %i: %f" %(i, cost))

    return parameters

# %%
parameters = nn_model(X, Y, n_h=2, num_iterations=3000, learning_rate=1.2, print_cost=True)
print("W1 = " + str(parameters["W1"]))
print("b1 = " + str(parameters["b1"]))
print("W2 = " + str(parameters["W2"]))
print("b2 = " + str(parameters["b2"]))

W1 = parameters["W1"]
b1 = parameters["b1"]
W2 = parameters["W2"]
b2 = parameters["b2"]
# Out:
# Cost after iteration 0: 0.693151
# Cost after iteration 1: 0.693149
# Cost after iteration 2: 0.693149
# Cost after iteration 3: 0.693148
# Cost after iteration 4: 0.693148
# Cost after iteration 5: 0.693148
# Cost after iteration 6: 0.693148
# Cost after iteration 7: 0.693148
# Cost after iteration 8: 0.693148
# Cost after iteration 9: 0.693148
# Cost after iteration 10: 0.693148
# Cost after iteration 11: 0.693148
# Cost after iteration 12: 0.693148
# Cost after iteration 13: 0.693148
# Cost after iteration 14: 0.693148
# Cost after iteration 15: 0.693148
# Cost after iteration 16: 0.693148
# Cost after iteration 17: 0.693148
# Cost after iteration 18: 0.693148
# Cost after iteration 19: 0.693148
# Cost after iteration 20: 0.693148
# Cost after iteration 21: 0.693147
# Cost after iteration 22: 0.693147
# Cost after iteration 23: 0.693147
# Cost after iteration 24: 0.693147
# Cost after iteration 25: 0.693147
# Cost after iteration 26: 0.693147
# Cost after iteration 27: 0.693147
# Cost after iteration 28: 0.693147
# Cost after iteration 29: 0.693147
# Cost after iteration 30: 0.693147
# Cost after iteration 31: 0.693147
# Cost after iteration 32: 0.693147
# Cost after iteration 33: 0.693147
# Cost after iteration 34: 0.693147
# Cost after iteration 35: 0.693147
# Cost after iteration 36: 0.693147
# Cost after iteration 37: 0.693147
# Cost after iteration 38: 0.693147
# Cost after iteration 39: 0.693147
# Cost after iteration 40: 0.693147
# Cost after iteration 41: 0.693147
# Cost after iteration 42: 0.693147
# Cost after iteration 43: 0.693147
# Cost after iteration 44: 0.693147
# Cost after iteration 45: 0.693147
# Cost after iteration 46: 0.693147
# Cost after iteration 47: 0.693147
# Cost after iteration 48: 0.693147
# Cost after iteration 49: 0.693147
# Cost after iteration 50: 0.693146
# Cost after iteration 51: 0.693146
# Cost after iteration 52: 0.693146
# Cost after iteration 53: 0.693146
# Cost after iteration 54: 0.693146
# Cost after iteration 55: 0.693146
# Cost after iteration 56: 0.693146
# Cost after iteration 57: 0.693146
# Cost after iteration 58: 0.693146
# Cost after iteration 59: 0.693146
# Cost after iteration 60: 0.693146
# Cost after iteration 61: 0.693146
# Cost after iteration 62: 0.693146
# Cost after iteration 63: 0.693146
# Cost after iteration 64: 0.693146
# Cost after iteration 65: 0.693146
# Cost after iteration 66: 0.693146
# Cost after iteration 67: 0.693146
# Cost after iteration 68: 0.693146
# Cost after iteration 69: 0.693146
# Cost after iteration 70: 0.693146
# Cost after iteration 71: 0.693146
# Cost after iteration 72: 0.693146
# Cost after iteration 73: 0.693146
# Cost after iteration 74: 0.693146
# Cost after iteration 75: 0.693146
# Cost after iteration 76: 0.693145
# Cost after iteration 77: 0.693145
# Cost after iteration 78: 0.693145
# Cost after iteration 79: 0.693145
# Cost after iteration 80: 0.693145
# Cost after iteration 81: 0.693145
# Cost after iteration 82: 0.693145
# Cost after iteration 83: 0.693145
# Cost after iteration 84: 0.693145
# Cost after iteration 85: 0.693145
# Cost after iteration 86: 0.693145
# Cost after iteration 87: 0.693145
# Cost after iteration 88: 0.693145
# Cost after iteration 89: 0.693145
# Cost after iteration 90: 0.693145
# Cost after iteration 91: 0.693145
# Cost after iteration 92: 0.693145
# Cost after iteration 93: 0.693145
# Cost after iteration 94: 0.693145
# Cost after iteration 95: 0.693145
# Cost after iteration 96: 0.693144
# Cost after iteration 97: 0.693144
# Cost after iteration 98: 0.693144
# Cost after iteration 99: 0.693144
# Cost after iteration 100: 0.693144
# Cost after iteration 101: 0.693144
# Cost after iteration 102: 0.693144
# Cost after iteration 103: 0.693144
# Cost after iteration 104: 0.693144
# Cost after iteration 105: 0.693144
# Cost after iteration 106: 0.693144
# Cost after iteration 107: 0.693144
# Cost after iteration 108: 0.693144
# Cost after iteration 109: 0.693144
# Cost after iteration 110: 0.693144
# Cost after iteration 111: 0.693144
# Cost after iteration 112: 0.693144
# Cost after iteration 113: 0.693143
# Cost after iteration 114: 0.693143
# Cost after iteration 115: 0.693143
# Cost after iteration 116: 0.693143
# Cost after iteration 117: 0.693143
# Cost after iteration 118: 0.693143
# Cost after iteration 119: 0.693143
# Cost after iteration 120: 0.693143
# Cost after iteration 121: 0.693143
# Cost after iteration 122: 0.693143
# Cost after iteration 123: 0.693143
# Cost after iteration 124: 0.693143
# Cost after iteration 125: 0.693143
# Cost after iteration 126: 0.693142
# Cost after iteration 127: 0.693142
# Cost after iteration 128: 0.693142
# Cost after iteration 129: 0.693142
# Cost after iteration 130: 0.693142
# Cost after iteration 131: 0.693142
# Cost after iteration 132: 0.693142
# Cost after iteration 133: 0.693142
# Cost after iteration 134: 0.693142
# Cost after iteration 135: 0.693142
# Cost after iteration 136: 0.693142
# Cost after iteration 137: 0.693141
# Cost after iteration 138: 0.693141
# Cost after iteration 139: 0.693141
# Cost after iteration 140: 0.693141
# Cost after iteration 141: 0.693141
# Cost after iteration 142: 0.693141
# Cost after iteration 143: 0.693141
# Cost after iteration 144: 0.693141
# Cost after iteration 145: 0.693141
# Cost after iteration 146: 0.693141
# Cost after iteration 147: 0.693140
# Cost after iteration 148: 0.693140
# Cost after iteration 149: 0.693140
# Cost after iteration 150: 0.693140
# Cost after iteration 151: 0.693140
# Cost after iteration 152: 0.693140
# Cost after iteration 153: 0.693140
# Cost after iteration 154: 0.693140
# Cost after iteration 155: 0.693139
# Cost after iteration 156: 0.693139
# Cost after iteration 157: 0.693139
# Cost after iteration 158: 0.693139
# Cost after iteration 159: 0.693139
# Cost after iteration 160: 0.693139
# Cost after iteration 161: 0.693139
# Cost after iteration 162: 0.693138
# Cost after iteration 163: 0.693138
# Cost after iteration 164: 0.693138
# Cost after iteration 165: 0.693138
# Cost after iteration 166: 0.693138
# Cost after iteration 167: 0.693138
# Cost after iteration 168: 0.693138
# Cost after iteration 169: 0.693137
# Cost after iteration 170: 0.693137
# Cost after iteration 171: 0.693137
# Cost after iteration 172: 0.693137
# Cost after iteration 173: 0.693137
# Cost after iteration 174: 0.693137
# Cost after iteration 175: 0.693136
# Cost after iteration 176: 0.693136
# Cost after iteration 177: 0.693136
# Cost after iteration 178: 0.693136
# Cost after iteration 179: 0.693136
# Cost after iteration 180: 0.693135
# Cost after iteration 181: 0.693135
# Cost after iteration 182: 0.693135
# Cost after iteration 183: 0.693135
# Cost after iteration 184: 0.693135
# Cost after iteration 185: 0.693134
# Cost after iteration 186: 0.693134
# Cost after iteration 187: 0.693134
# Cost after iteration 188: 0.693134
# Cost after iteration 189: 0.693133
# Cost after iteration 190: 0.693133
# Cost after iteration 191: 0.693133
# Cost after iteration 192: 0.693133
# Cost after iteration 193: 0.693132
# Cost after iteration 194: 0.693132
# Cost after iteration 195: 0.693132
# Cost after iteration 196: 0.693132
# Cost after iteration 197: 0.693131
# Cost after iteration 198: 0.693131
# Cost after iteration 199: 0.693131
# Cost after iteration 200: 0.693131
# Cost after iteration 201: 0.693130
# Cost after iteration 202: 0.693130
# Cost after iteration 203: 0.693130
# Cost after iteration 204: 0.693129
# Cost after iteration 205: 0.693129
# Cost after iteration 206: 0.693129
# Cost after iteration 207: 0.693128
# Cost after iteration 208: 0.693128
# Cost after iteration 209: 0.693128
# Cost after iteration 210: 0.693127
# Cost after iteration 211: 0.693127
# Cost after iteration 212: 0.693127
# Cost after iteration 213: 0.693126
# Cost after iteration 214: 0.693126
# Cost after iteration 215: 0.693125
# Cost after iteration 216: 0.693125
# Cost after iteration 217: 0.693125
# Cost after iteration 218: 0.693124
# Cost after iteration 219: 0.693124
# Cost after iteration 220: 0.693123
# Cost after iteration 221: 0.693123
# Cost after iteration 222: 0.693122
# Cost after iteration 223: 0.693122
# Cost after iteration 224: 0.693121
# Cost after iteration 225: 0.693121
# Cost after iteration 226: 0.693120
# Cost after iteration 227: 0.693120
# Cost after iteration 228: 0.693119
# Cost after iteration 229: 0.693119
# Cost after iteration 230: 0.693118
# Cost after iteration 231: 0.693118
# Cost after iteration 232: 0.693117
# Cost after iteration 233: 0.693116
# Cost after iteration 234: 0.693116
# Cost after iteration 235: 0.693115
# Cost after iteration 236: 0.693114
# Cost after iteration 237: 0.693114
# Cost after iteration 238: 0.693113
# Cost after iteration 239: 0.693112
# Cost after iteration 240: 0.693112
# Cost after iteration 241: 0.693111
# Cost after iteration 242: 0.693110
# Cost after iteration 243: 0.693109
# Cost after iteration 244: 0.693108
# Cost after iteration 245: 0.693108
# Cost after iteration 246: 0.693107
# Cost after iteration 247: 0.693106
# Cost after iteration 248: 0.693105
# Cost after iteration 249: 0.693104
# Cost after iteration 250: 0.693103
# Cost after iteration 251: 0.693102
# Cost after iteration 252: 0.693101
# Cost after iteration 253: 0.693100
# Cost after iteration 254: 0.693099
# Cost after iteration 255: 0.693097
# Cost after iteration 256: 0.693096
# Cost after iteration 257: 0.693095
# Cost after iteration 258: 0.693094
# Cost after iteration 259: 0.693092
# Cost after iteration 260: 0.693091
# Cost after iteration 261: 0.693089
# Cost after iteration 262: 0.693088
# Cost after iteration 263: 0.693086
# Cost after iteration 264: 0.693085
# Cost after iteration 265: 0.693083
# Cost after iteration 266: 0.693081
# Cost after iteration 267: 0.693080
# Cost after iteration 268: 0.693078
# Cost after iteration 269: 0.693076
# Cost after iteration 270: 0.693074
# Cost after iteration 271: 0.693071
# Cost after iteration 272: 0.693069
# Cost after iteration 273: 0.693067
# Cost after iteration 274: 0.693064
# Cost after iteration 275: 0.693062
# Cost after iteration 276: 0.693059
# Cost after iteration 277: 0.693056
# Cost after iteration 278: 0.693054
# Cost after iteration 279: 0.693050
# Cost after iteration 280: 0.693047
# Cost after iteration 281: 0.693044
# Cost after iteration 282: 0.693040
# Cost after iteration 283: 0.693037
# Cost after iteration 284: 0.693033
# Cost after iteration 285: 0.693028
# Cost after iteration 286: 0.693024
# Cost after iteration 287: 0.693019
# Cost after iteration 288: 0.693014
# Cost after iteration 289: 0.693009
# Cost after iteration 290: 0.693004
# Cost after iteration 291: 0.692998
# Cost after iteration 292: 0.692992
# Cost after iteration 293: 0.692985
# Cost after iteration 294: 0.692978
# Cost after iteration 295: 0.692971
# Cost after iteration 296: 0.692963
# Cost after iteration 297: 0.692954
# Cost after iteration 298: 0.692945
# Cost after iteration 299: 0.692935
# Cost after iteration 300: 0.692925
# Cost after iteration 301: 0.692913
# Cost after iteration 302: 0.692901
# Cost after iteration 303: 0.692888
# Cost after iteration 304: 0.692874
# Cost after iteration 305: 0.692859
# Cost after iteration 306: 0.692842
# Cost after iteration 307: 0.692824
# Cost after iteration 308: 0.692805
# Cost after iteration 309: 0.692784
# Cost after iteration 310: 0.692760
# Cost after iteration 311: 0.692735
# Cost after iteration 312: 0.692707
# Cost after iteration 313: 0.692677
# Cost after iteration 314: 0.692644
# Cost after iteration 315: 0.692607
# Cost after iteration 316: 0.692567
# Cost after iteration 317: 0.692522
# Cost after iteration 318: 0.692473
# Cost after iteration 319: 0.692418
# Cost after iteration 320: 0.692357
# Cost after iteration 321: 0.692289
# Cost after iteration 322: 0.692214
# Cost after iteration 323: 0.692129
# Cost after iteration 324: 0.692034
# Cost after iteration 325: 0.691928
# Cost after iteration 326: 0.691809
# Cost after iteration 327: 0.691676
# Cost after iteration 328: 0.691525
# Cost after iteration 329: 0.691356
# Cost after iteration 330: 0.691165
# Cost after iteration 331: 0.690949
# Cost after iteration 332: 0.690706
# Cost after iteration 333: 0.690432
# Cost after iteration 334: 0.690124
# Cost after iteration 335: 0.689776
# Cost after iteration 336: 0.689385
# Cost after iteration 337: 0.688946
# Cost after iteration 338: 0.688455
# Cost after iteration 339: 0.687905
# Cost after iteration 340: 0.687293
# Cost after iteration 341: 0.686614
# Cost after iteration 342: 0.685862
# Cost after iteration 343: 0.685035
# Cost after iteration 344: 0.684128
# Cost after iteration 345: 0.683140
# Cost after iteration 346: 0.682067
# Cost after iteration 347: 0.680909
# Cost after iteration 348: 0.679667
# Cost after iteration 349: 0.678340
# Cost after iteration 350: 0.676932
# Cost after iteration 351: 0.675444
# Cost after iteration 352: 0.673880
# Cost after iteration 353: 0.672244
# Cost after iteration 354: 0.670541
# Cost after iteration 355: 0.668774
# Cost after iteration 356: 0.666948
# Cost after iteration 357: 0.665068
# Cost after iteration 358: 0.663138
# Cost after iteration 359: 0.661161
# Cost after iteration 360: 0.659141
# Cost after iteration 361: 0.657082
# Cost after iteration 362: 0.654985
# Cost after iteration 363: 0.652855
# Cost after iteration 364: 0.650695
# Cost after iteration 365: 0.648508
# Cost after iteration 366: 0.646299
# Cost after iteration 367: 0.644075
# Cost after iteration 368: 0.641842
# Cost after iteration 369: 0.639610
# Cost after iteration 370: 0.637388
# Cost after iteration 371: 0.635185
# Cost after iteration 372: 0.633011
# Cost after iteration 373: 0.630873
# Cost after iteration 374: 0.628778
# Cost after iteration 375: 0.626730
# Cost after iteration 376: 0.624731
# Cost after iteration 377: 0.622784
# Cost after iteration 378: 0.620889
# Cost after iteration 379: 0.619045
# Cost after iteration 380: 0.617253
# Cost after iteration 381: 0.615509
# Cost after iteration 382: 0.613815
# Cost after iteration 383: 0.612167
# Cost after iteration 384: 0.610564
# Cost after iteration 385: 0.609004
# Cost after iteration 386: 0.607486
# Cost after iteration 387: 0.606008
# Cost after iteration 388: 0.604568
# Cost after iteration 389: 0.603165
# Cost after iteration 390: 0.601796
# Cost after iteration 391: 0.600461
# Cost after iteration 392: 0.599158
# Cost after iteration 393: 0.597886
# Cost after iteration 394: 0.596642
# Cost after iteration 395: 0.595427
# Cost after iteration 396: 0.594237
# Cost after iteration 397: 0.593073
# Cost after iteration 398: 0.591933
# Cost after iteration 399: 0.590815
# Cost after iteration 400: 0.589719
# Cost after iteration 401: 0.588644
# Cost after iteration 402: 0.587589
# Cost after iteration 403: 0.586552
# Cost after iteration 404: 0.585533
# Cost after iteration 405: 0.584531
# Cost after iteration 406: 0.583545
# Cost after iteration 407: 0.582574
# Cost after iteration 408: 0.581618
# Cost after iteration 409: 0.580676
# Cost after iteration 410: 0.579747
# Cost after iteration 411: 0.578830
# Cost after iteration 412: 0.577924
# Cost after iteration 413: 0.577030
# Cost after iteration 414: 0.576147
# Cost after iteration 415: 0.575273
# Cost after iteration 416: 0.574409
# Cost after iteration 417: 0.573554
# Cost after iteration 418: 0.572707
# Cost after iteration 419: 0.571868
# Cost after iteration 420: 0.571036
# Cost after iteration 421: 0.570211
# Cost after iteration 422: 0.569393
# Cost after iteration 423: 0.568581
# Cost after iteration 424: 0.567774
# Cost after iteration 425: 0.566973
# Cost after iteration 426: 0.566177
# Cost after iteration 427: 0.565385
# Cost after iteration 428: 0.564597
# Cost after iteration 429: 0.563814
# Cost after iteration 430: 0.563033
# Cost after iteration 431: 0.562256
# Cost after iteration 432: 0.561482
# Cost after iteration 433: 0.560711
# Cost after iteration 434: 0.559942
# Cost after iteration 435: 0.559174
# Cost after iteration 436: 0.558409
# Cost after iteration 437: 0.557645
# Cost after iteration 438: 0.556883
# Cost after iteration 439: 0.556121
# Cost after iteration 440: 0.555360
# Cost after iteration 441: 0.554600
# Cost after iteration 442: 0.553840
# Cost after iteration 443: 0.553080
# Cost after iteration 444: 0.552319
# Cost after iteration 445: 0.551558
# Cost after iteration 446: 0.550796
# Cost after iteration 447: 0.550033
# Cost after iteration 448: 0.549268
# Cost after iteration 449: 0.548501
# Cost after iteration 450: 0.547732
# Cost after iteration 451: 0.546959
# Cost after iteration 452: 0.546182
# Cost after iteration 453: 0.545400
# Cost after iteration 454: 0.544611
# Cost after iteration 455: 0.543813
# Cost after iteration 456: 0.543004
# Cost after iteration 457: 0.542179
# Cost after iteration 458: 0.541332
# Cost after iteration 459: 0.540452
# Cost after iteration 460: 0.539520
# Cost after iteration 461: 0.538503
# Cost after iteration 462: 0.537336
# Cost after iteration 463: 0.535877
# Cost after iteration 464: 0.533801
# Cost after iteration 465: 0.530327
# Cost after iteration 466: 0.523780
# Cost after iteration 467: 0.512124
# Cost after iteration 468: 0.495399
# Cost after iteration 469: 0.477043
# Cost after iteration 470: 0.460680
# Cost after iteration 471: 0.451281
# Cost after iteration 472: 0.463907
# Cost after iteration 473: 0.523319
# Cost after iteration 474: 0.496439
# Cost after iteration 475: 0.523699
# Cost after iteration 476: 0.422892
# Cost after iteration 477: 0.420547
# Cost after iteration 478: 0.406188
# Cost after iteration 479: 0.399205
# Cost after iteration 480: 0.389479
# Cost after iteration 481: 0.383392
# Cost after iteration 482: 0.377809
# Cost after iteration 483: 0.373536
# Cost after iteration 484: 0.369778
# Cost after iteration 485: 0.366456
# Cost after iteration 486: 0.363374
# Cost after iteration 487: 0.360466
# Cost after iteration 488: 0.357682
# Cost after iteration 489: 0.354999
# Cost after iteration 490: 0.352404
# Cost after iteration 491: 0.349888
# Cost after iteration 492: 0.347446
# Cost after iteration 493: 0.345073
# Cost after iteration 494: 0.342767
# Cost after iteration 495: 0.340525
# Cost after iteration 496: 0.338344
# Cost after iteration 497: 0.336220
# Cost after iteration 498: 0.334152
# Cost after iteration 499: 0.332138
# Cost after iteration 500: 0.330175
# Cost after iteration 501: 0.328261
# Cost after iteration 502: 0.326394
# Cost after iteration 503: 0.324572
# Cost after iteration 504: 0.322794
# Cost after iteration 505: 0.321058
# Cost after iteration 506: 0.319362
# Cost after iteration 507: 0.317704
# Cost after iteration 508: 0.316084
# Cost after iteration 509: 0.314500
# Cost after iteration 510: 0.312950
# Cost after iteration 511: 0.311433
# Cost after iteration 512: 0.309949
# Cost after iteration 513: 0.308495
# Cost after iteration 514: 0.307071
# Cost after iteration 515: 0.305676
# Cost after iteration 516: 0.304308
# Cost after iteration 517: 0.302967
# Cost after iteration 518: 0.301653
# Cost after iteration 519: 0.300363
# Cost after iteration 520: 0.299097
# Cost after iteration 521: 0.297854
# Cost after iteration 522: 0.296634
# Cost after iteration 523: 0.295436
# Cost after iteration 524: 0.294258
# Cost after iteration 525: 0.293102
# Cost after iteration 526: 0.291965
# Cost after iteration 527: 0.290847
# Cost after iteration 528: 0.289747
# Cost after iteration 529: 0.288666
# Cost after iteration 530: 0.287601
# Cost after iteration 531: 0.286554
# Cost after iteration 532: 0.285523
# Cost after iteration 533: 0.284508
# Cost after iteration 534: 0.283508
# Cost after iteration 535: 0.282524
# Cost after iteration 536: 0.281553
# Cost after iteration 537: 0.280597
# Cost after iteration 538: 0.279654
# Cost after iteration 539: 0.278725
# Cost after iteration 540: 0.277809
# Cost after iteration 541: 0.276905
# Cost after iteration 542: 0.276013
# Cost after iteration 543: 0.275134
# Cost after iteration 544: 0.274265
# Cost after iteration 545: 0.273408
# Cost after iteration 546: 0.272562
# Cost after iteration 547: 0.271727
# Cost after iteration 548: 0.270902
# Cost after iteration 549: 0.270087
# Cost after iteration 550: 0.269282
# Cost after iteration 551: 0.268487
# Cost after iteration 552: 0.267701
# Cost after iteration 553: 0.266924
# Cost after iteration 554: 0.266156
# Cost after iteration 555: 0.265397
# Cost after iteration 556: 0.264647
# Cost after iteration 557: 0.263905
# Cost after iteration 558: 0.263171
# Cost after iteration 559: 0.262444
# Cost after iteration 560: 0.261726
# Cost after iteration 561: 0.261015
# Cost after iteration 562: 0.260312
# Cost after iteration 563: 0.259616
# Cost after iteration 564: 0.258928
# Cost after iteration 565: 0.258246
# Cost after iteration 566: 0.257571
# Cost after iteration 567: 0.256903
# Cost after iteration 568: 0.256241
# Cost after iteration 569: 0.255586
# Cost after iteration 570: 0.254938
# Cost after iteration 571: 0.254295
# Cost after iteration 572: 0.253659
# Cost after iteration 573: 0.253029
# Cost after iteration 574: 0.252404
# Cost after iteration 575: 0.251786
# Cost after iteration 576: 0.251173
# Cost after iteration 577: 0.250566
# Cost after iteration 578: 0.249965
# Cost after iteration 579: 0.249369
# Cost after iteration 580: 0.248778
# Cost after iteration 581: 0.248193
# Cost after iteration 582: 0.247612
# Cost after iteration 583: 0.247037
# Cost after iteration 584: 0.246468
# Cost after iteration 585: 0.245903
# Cost after iteration 586: 0.245343
# Cost after iteration 587: 0.244788
# Cost after iteration 588: 0.244238
# Cost after iteration 589: 0.243692
# Cost after iteration 590: 0.243152
# Cost after iteration 591: 0.242616
# Cost after iteration 592: 0.242084
# Cost after iteration 593: 0.241558
# Cost after iteration 594: 0.241035
# Cost after iteration 595: 0.240517
# Cost after iteration 596: 0.240004
# Cost after iteration 597: 0.239495
# Cost after iteration 598: 0.238990
# Cost after iteration 599: 0.238490
# Cost after iteration 600: 0.237994
# Cost after iteration 601: 0.237502
# Cost after iteration 602: 0.237014
# Cost after iteration 603: 0.236530
# Cost after iteration 604: 0.236051
# Cost after iteration 605: 0.235576
# Cost after iteration 606: 0.235104
# Cost after iteration 607: 0.234637
# Cost after iteration 608: 0.234173
# Cost after iteration 609: 0.233714
# Cost after iteration 610: 0.233258
# Cost after iteration 611: 0.232806
# Cost after iteration 612: 0.232359
# Cost after iteration 613: 0.231914
# Cost after iteration 614: 0.231474
# Cost after iteration 615: 0.231038
# Cost after iteration 616: 0.230605
# Cost after iteration 617: 0.230176
# Cost after iteration 618: 0.229750
# Cost after iteration 619: 0.229329
# Cost after iteration 620: 0.228911
# Cost after iteration 621: 0.228496
# Cost after iteration 622: 0.228085
# Cost after iteration 623: 0.227678
# Cost after iteration 624: 0.227274
# Cost after iteration 625: 0.226874
# Cost after iteration 626: 0.226477
# Cost after iteration 627: 0.226083
# Cost after iteration 628: 0.225693
# Cost after iteration 629: 0.225306
# Cost after iteration 630: 0.224923
# Cost after iteration 631: 0.224543
# Cost after iteration 632: 0.224167
# Cost after iteration 633: 0.223793
# Cost after iteration 634: 0.223423
# Cost after iteration 635: 0.223057
# Cost after iteration 636: 0.222693
# Cost after iteration 637: 0.222333
# Cost after iteration 638: 0.221976
# Cost after iteration 639: 0.221622
# Cost after iteration 640: 0.221271
# Cost after iteration 641: 0.220923
# Cost after iteration 642: 0.220579
# Cost after iteration 643: 0.220237
# Cost after iteration 644: 0.219899
# Cost after iteration 645: 0.219563
# Cost after iteration 646: 0.219231
# Cost after iteration 647: 0.218901
# Cost after iteration 648: 0.218574
# Cost after iteration 649: 0.218251
# Cost after iteration 650: 0.217930
# Cost after iteration 651: 0.217612
# Cost after iteration 652: 0.217297
# Cost after iteration 653: 0.216985
# Cost after iteration 654: 0.216675
# Cost after iteration 655: 0.216369
# Cost after iteration 656: 0.216065
# Cost after iteration 657: 0.215764
# Cost after iteration 658: 0.215465
# Cost after iteration 659: 0.215170
# Cost after iteration 660: 0.214877
# Cost after iteration 661: 0.214586
# Cost after iteration 662: 0.214299
# Cost after iteration 663: 0.214013
# Cost after iteration 664: 0.213731
# Cost after iteration 665: 0.213451
# Cost after iteration 666: 0.213173
# Cost after iteration 667: 0.212898
# Cost after iteration 668: 0.212626
# Cost after iteration 669: 0.212356
# Cost after iteration 670: 0.212088
# Cost after iteration 671: 0.211823
# Cost after iteration 672: 0.211560
# Cost after iteration 673: 0.211300
# Cost after iteration 674: 0.211042
# Cost after iteration 675: 0.210786
# Cost after iteration 676: 0.210533
# Cost after iteration 677: 0.210283
# Cost after iteration 678: 0.210037
# Cost after iteration 679: 0.209801
# Cost after iteration 680: 0.209591
# Cost after iteration 681: 0.209468
# Cost after iteration 682: 0.209644
# Cost after iteration 683: 0.210861
# Cost after iteration 684: 0.215905
# Cost after iteration 685: 0.235141
# Cost after iteration 686: 0.316384
# Cost after iteration 687: 0.567938
# Cost after iteration 688: 0.882680
# Cost after iteration 689: 0.311729
# Cost after iteration 690: 0.273985
# Cost after iteration 691: 0.253303
# Cost after iteration 692: 0.236755
# Cost after iteration 693: 0.225245
# Cost after iteration 694: 0.220237
# Cost after iteration 695: 0.216473
# Cost after iteration 696: 0.214791
# Cost after iteration 697: 0.213577
# Cost after iteration 698: 0.212825
# Cost after iteration 699: 0.212221
# Cost after iteration 700: 0.211728
# Cost after iteration 701: 0.211284
# Cost after iteration 702: 0.210876
# Cost after iteration 703: 0.210489
# Cost after iteration 704: 0.210119
# Cost after iteration 705: 0.209761
# Cost after iteration 706: 0.209414
# Cost after iteration 707: 0.209076
# Cost after iteration 708: 0.208747
# Cost after iteration 709: 0.208424
# Cost after iteration 710: 0.208109
# Cost after iteration 711: 0.207799
# Cost after iteration 712: 0.207496
# Cost after iteration 713: 0.207199
# Cost after iteration 714: 0.206907
# Cost after iteration 715: 0.206620
# Cost after iteration 716: 0.206338
# Cost after iteration 717: 0.206061
# Cost after iteration 718: 0.205789
# Cost after iteration 719: 0.205521
# Cost after iteration 720: 0.205258
# Cost after iteration 721: 0.205000
# Cost after iteration 722: 0.204746
# Cost after iteration 723: 0.204496
# Cost after iteration 724: 0.204251
# Cost after iteration 725: 0.204011
# Cost after iteration 726: 0.203776
# Cost after iteration 727: 0.203547
# Cost after iteration 728: 0.203326
# Cost after iteration 729: 0.203114
# Cost after iteration 730: 0.202916
# Cost after iteration 731: 0.202738
# Cost after iteration 732: 0.202592
# Cost after iteration 733: 0.202501
# Cost after iteration 734: 0.202506
# Cost after iteration 735: 0.202687
# Cost after iteration 736: 0.203189
# Cost after iteration 737: 0.204342
# Cost after iteration 738: 0.206725
# Cost after iteration 739: 0.211910
# Cost after iteration 740: 0.222781
# Cost after iteration 741: 0.249298
# Cost after iteration 742: 0.303631
# Cost after iteration 743: 0.451059
# Cost after iteration 744: 0.465257
# Cost after iteration 745: 0.539308
# Cost after iteration 746: 0.297914
# Cost after iteration 747: 0.264773
# Cost after iteration 748: 0.234834
# Cost after iteration 749: 0.224522
# Cost after iteration 750: 0.216806
# Cost after iteration 751: 0.214809
# Cost after iteration 752: 0.211557
# Cost after iteration 753: 0.210379
# Cost after iteration 754: 0.208706
# Cost after iteration 755: 0.207879
# Cost after iteration 756: 0.206923
# Cost after iteration 757: 0.206325
# Cost after iteration 758: 0.205704
# Cost after iteration 759: 0.205240
# Cost after iteration 760: 0.204781
# Cost after iteration 761: 0.204395
# Cost after iteration 762: 0.204017
# Cost after iteration 763: 0.203677
# Cost after iteration 764: 0.203345
# Cost after iteration 765: 0.203033
# Cost after iteration 766: 0.202728
# Cost after iteration 767: 0.202436
# Cost after iteration 768: 0.202150
# Cost after iteration 769: 0.201872
# Cost after iteration 770: 0.201600
# Cost after iteration 771: 0.201334
# Cost after iteration 772: 0.201073
# Cost after iteration 773: 0.200818
# Cost after iteration 774: 0.200568
# Cost after iteration 775: 0.200322
# Cost after iteration 776: 0.200080
# Cost after iteration 777: 0.199843
# Cost after iteration 778: 0.199610
# Cost after iteration 779: 0.199382
# Cost after iteration 780: 0.199157
# Cost after iteration 781: 0.198936
# Cost after iteration 782: 0.198720
# Cost after iteration 783: 0.198507
# Cost after iteration 784: 0.198298
# Cost after iteration 785: 0.198094
# Cost after iteration 786: 0.197893
# Cost after iteration 787: 0.197696
# Cost after iteration 788: 0.197503
# Cost after iteration 789: 0.197314
# Cost after iteration 790: 0.197130
# Cost after iteration 791: 0.196950
# Cost after iteration 792: 0.196774
# Cost after iteration 793: 0.196605
# Cost after iteration 794: 0.196440
# Cost after iteration 795: 0.196285
# Cost after iteration 796: 0.196137
# Cost after iteration 797: 0.196003
# Cost after iteration 798: 0.195885
# Cost after iteration 799: 0.195795
# Cost after iteration 800: 0.195740
# Cost after iteration 801: 0.195752
# Cost after iteration 802: 0.195852
# Cost after iteration 803: 0.196135
# Cost after iteration 804: 0.196669
# Cost after iteration 805: 0.197766
# Cost after iteration 806: 0.199660
# Cost after iteration 807: 0.203547
# Cost after iteration 808: 0.210421
# Cost after iteration 809: 0.226120
# Cost after iteration 810: 0.255615
# Cost after iteration 811: 0.339164
# Cost after iteration 812: 0.424550
# Cost after iteration 813: 0.597025
# Cost after iteration 814: 0.349594
# Cost after iteration 815: 0.375932
# Cost after iteration 816: 0.285218
# Cost after iteration 817: 0.272728
# Cost after iteration 818: 0.230174
# Cost after iteration 819: 0.223830
# Cost after iteration 820: 0.211616
# Cost after iteration 821: 0.208867
# Cost after iteration 822: 0.204862
# Cost after iteration 823: 0.203376
# Cost after iteration 824: 0.201809
# Cost after iteration 825: 0.200994
# Cost after iteration 826: 0.200250
# Cost after iteration 827: 0.199747
# Cost after iteration 828: 0.199295
# Cost after iteration 829: 0.198929
# Cost after iteration 830: 0.198590
# Cost after iteration 831: 0.198286
# Cost after iteration 832: 0.197998
# Cost after iteration 833: 0.197726
# Cost after iteration 834: 0.197465
# Cost after iteration 835: 0.197213
# Cost after iteration 836: 0.196969
# Cost after iteration 837: 0.196732
# Cost after iteration 838: 0.196501
# Cost after iteration 839: 0.196276
# Cost after iteration 840: 0.196056
# Cost after iteration 841: 0.195841
# Cost after iteration 842: 0.195631
# Cost after iteration 843: 0.195425
# Cost after iteration 844: 0.195224
# Cost after iteration 845: 0.195028
# Cost after iteration 846: 0.194835
# Cost after iteration 847: 0.194647
# Cost after iteration 848: 0.194463
# Cost after iteration 849: 0.194282
# Cost after iteration 850: 0.194106
# Cost after iteration 851: 0.193933
# Cost after iteration 852: 0.193763
# Cost after iteration 853: 0.193598
# Cost after iteration 854: 0.193436
# Cost after iteration 855: 0.193277
# Cost after iteration 856: 0.193122
# Cost after iteration 857: 0.192970
# Cost after iteration 858: 0.192821
# Cost after iteration 859: 0.192675
# Cost after iteration 860: 0.192533
# Cost after iteration 861: 0.192393
# Cost after iteration 862: 0.192257
# Cost after iteration 863: 0.192124
# Cost after iteration 864: 0.191994
# Cost after iteration 865: 0.191867
# Cost after iteration 866: 0.191743
# Cost after iteration 867: 0.191622
# Cost after iteration 868: 0.191505
# Cost after iteration 869: 0.191392
# Cost after iteration 870: 0.191285
# Cost after iteration 871: 0.191184
# Cost after iteration 872: 0.191091
# Cost after iteration 873: 0.191012
# Cost after iteration 874: 0.190951
# Cost after iteration 875: 0.190923
# Cost after iteration 876: 0.190944
# Cost after iteration 877: 0.191058
# Cost after iteration 878: 0.191312
# Cost after iteration 879: 0.191865
# Cost after iteration 880: 0.192860
# Cost after iteration 881: 0.194917
# Cost after iteration 882: 0.198524
# Cost after iteration 883: 0.206604
# Cost after iteration 884: 0.221519
# Cost after iteration 885: 0.262372
# Cost after iteration 886: 0.331307
# Cost after iteration 887: 0.512114
# Cost after iteration 888: 0.441545
# Cost after iteration 889: 0.550082
# Cost after iteration 890: 0.348163
# Cost after iteration 891: 0.363250
# Cost after iteration 892: 0.260516
# Cost after iteration 893: 0.248648
# Cost after iteration 894: 0.215407
# Cost after iteration 895: 0.210800
# Cost after iteration 896: 0.203797
# Cost after iteration 897: 0.201681
# Cost after iteration 898: 0.199515
# Cost after iteration 899: 0.198515
# Cost after iteration 900: 0.197671
# Cost after iteration 901: 0.197134
# Cost after iteration 902: 0.196679
# Cost after iteration 903: 0.196315
# Cost after iteration 904: 0.195987
# Cost after iteration 905: 0.195691
# Cost after iteration 906: 0.195413
# Cost after iteration 907: 0.195151
# Cost after iteration 908: 0.194899
# Cost after iteration 909: 0.194656
# Cost after iteration 910: 0.194421
# Cost after iteration 911: 0.194194
# Cost after iteration 912: 0.193972
# Cost after iteration 913: 0.193757
# Cost after iteration 914: 0.193548
# Cost after iteration 915: 0.193344
# Cost after iteration 916: 0.193145
# Cost after iteration 917: 0.192951
# Cost after iteration 918: 0.192762
# Cost after iteration 919: 0.192577
# Cost after iteration 920: 0.192397
# Cost after iteration 921: 0.192222
# Cost after iteration 922: 0.192051
# Cost after iteration 923: 0.191884
# Cost after iteration 924: 0.191721
# Cost after iteration 925: 0.191561
# Cost after iteration 926: 0.191406
# Cost after iteration 927: 0.191254
# Cost after iteration 928: 0.191107
# Cost after iteration 929: 0.190962
# Cost after iteration 930: 0.190821
# Cost after iteration 931: 0.190683
# Cost after iteration 932: 0.190549
# Cost after iteration 933: 0.190418
# Cost after iteration 934: 0.190290
# Cost after iteration 935: 0.190165
# Cost after iteration 936: 0.190043
# Cost after iteration 937: 0.189924
# Cost after iteration 938: 0.189807
# Cost after iteration 939: 0.189694
# Cost after iteration 940: 0.189583
# Cost after iteration 941: 0.189474
# Cost after iteration 942: 0.189368
# Cost after iteration 943: 0.189265
# Cost after iteration 944: 0.189164
# Cost after iteration 945: 0.189066
# Cost after iteration 946: 0.188969
# Cost after iteration 947: 0.188875
# Cost after iteration 948: 0.188784
# Cost after iteration 949: 0.188694
# Cost after iteration 950: 0.188607
# Cost after iteration 951: 0.188521
# Cost after iteration 952: 0.188438
# Cost after iteration 953: 0.188358
# Cost after iteration 954: 0.188280
# Cost after iteration 955: 0.188205
# Cost after iteration 956: 0.188133
# Cost after iteration 957: 0.188065
# Cost after iteration 958: 0.188004
# Cost after iteration 959: 0.187950
# Cost after iteration 960: 0.187909
# Cost after iteration 961: 0.187888
# Cost after iteration 962: 0.187895
# Cost after iteration 963: 0.187957
# Cost after iteration 964: 0.188098
# Cost after iteration 965: 0.188402
# Cost after iteration 966: 0.188932
# Cost after iteration 967: 0.189995
# Cost after iteration 968: 0.191755
# Cost after iteration 969: 0.195454
# Cost after iteration 970: 0.201540
# Cost after iteration 971: 0.216188
# Cost after iteration 972: 0.241800
# Cost after iteration 973: 0.322440
# Cost after iteration 974: 0.419520
# Cost after iteration 975: 0.683705
# Cost after iteration 976: 0.386578
# Cost after iteration 977: 0.496179
# Cost after iteration 978: 0.306363
# Cost after iteration 979: 0.282690
# Cost after iteration 980: 0.221389
# Cost after iteration 981: 0.208959
# Cost after iteration 982: 0.200568
# Cost after iteration 983: 0.197801
# Cost after iteration 984: 0.196052
# Cost after iteration 985: 0.195218
# Cost after iteration 986: 0.194632
# Cost after iteration 987: 0.194220
# Cost after iteration 988: 0.193874
# Cost after iteration 989: 0.193571
# Cost after iteration 990: 0.193292
# Cost after iteration 991: 0.193029
# Cost after iteration 992: 0.192779
# Cost after iteration 993: 0.192539
# Cost after iteration 994: 0.192309
# Cost after iteration 995: 0.192087
# Cost after iteration 996: 0.191872
# Cost after iteration 997: 0.191665
# Cost after iteration 998: 0.191464
# Cost after iteration 999: 0.191270
# Cost after iteration 1000: 0.191082
# Cost after iteration 1001: 0.190900
# Cost after iteration 1002: 0.190724
# Cost after iteration 1003: 0.190554
# Cost after iteration 1004: 0.190388
# Cost after iteration 1005: 0.190228
# Cost after iteration 1006: 0.190073
# Cost after iteration 1007: 0.189922
# Cost after iteration 1008: 0.189775
# Cost after iteration 1009: 0.189633
# Cost after iteration 1010: 0.189496
# Cost after iteration 1011: 0.189362
# Cost after iteration 1012: 0.189232
# Cost after iteration 1013: 0.189105
# Cost after iteration 1014: 0.188983
# Cost after iteration 1015: 0.188864
# Cost after iteration 1016: 0.188748
# Cost after iteration 1017: 0.188635
# Cost after iteration 1018: 0.188525
# Cost after iteration 1019: 0.188419
# Cost after iteration 1020: 0.188315
# Cost after iteration 1021: 0.188214
# Cost after iteration 1022: 0.188116
# Cost after iteration 1023: 0.188021
# Cost after iteration 1024: 0.187928
# Cost after iteration 1025: 0.187837
# Cost after iteration 1026: 0.187749
# Cost after iteration 1027: 0.187663
# Cost after iteration 1028: 0.187580
# Cost after iteration 1029: 0.187498
# Cost after iteration 1030: 0.187419
# Cost after iteration 1031: 0.187341
# Cost after iteration 1032: 0.187266
# Cost after iteration 1033: 0.187192
# Cost after iteration 1034: 0.187120
# Cost after iteration 1035: 0.187050
# Cost after iteration 1036: 0.186982
# Cost after iteration 1037: 0.186915
# Cost after iteration 1038: 0.186850
# Cost after iteration 1039: 0.186787
# Cost after iteration 1040: 0.186724
# Cost after iteration 1041: 0.186664
# Cost after iteration 1042: 0.186605
# Cost after iteration 1043: 0.186547
# Cost after iteration 1044: 0.186490
# Cost after iteration 1045: 0.186435
# Cost after iteration 1046: 0.186381
# Cost after iteration 1047: 0.186328
# Cost after iteration 1048: 0.186276
# Cost after iteration 1049: 0.186226
# Cost after iteration 1050: 0.186177
# Cost after iteration 1051: 0.186129
# Cost after iteration 1052: 0.186083
# Cost after iteration 1053: 0.186038
# Cost after iteration 1054: 0.185995
# Cost after iteration 1055: 0.185956
# Cost after iteration 1056: 0.185921
# Cost after iteration 1057: 0.185894
# Cost after iteration 1058: 0.185878
# Cost after iteration 1059: 0.185883
# Cost after iteration 1060: 0.185923
# Cost after iteration 1061: 0.186029
# Cost after iteration 1062: 0.186243
# Cost after iteration 1063: 0.186685
# Cost after iteration 1064: 0.187479
# Cost after iteration 1065: 0.189113
# Cost after iteration 1066: 0.191955
# Cost after iteration 1067: 0.198311
# Cost after iteration 1068: 0.209462
# Cost after iteration 1069: 0.240378
# Cost after iteration 1070: 0.296481
# Cost after iteration 1071: 0.480374
# Cost after iteration 1072: 0.508754
# Cost after iteration 1073: 0.823918
# Cost after iteration 1074: 0.351133
# Cost after iteration 1075: 0.395230
# Cost after iteration 1076: 0.226786
# Cost after iteration 1077: 0.212848
# Cost after iteration 1078: 0.200131
# Cost after iteration 1079: 0.196971
# Cost after iteration 1080: 0.195156
# Cost after iteration 1081: 0.194346
# Cost after iteration 1082: 0.193810
# Cost after iteration 1083: 0.193414
# Cost after iteration 1084: 0.193073
# Cost after iteration 1085: 0.192762
# Cost after iteration 1086: 0.192471
# Cost after iteration 1087: 0.192193
# Cost after iteration 1088: 0.191928
# Cost after iteration 1089: 0.191674
# Cost after iteration 1090: 0.191430
# Cost after iteration 1091: 0.191196
# Cost after iteration 1092: 0.190970
# Cost after iteration 1093: 0.190754
# Cost after iteration 1094: 0.190545
# Cost after iteration 1095: 0.190344
# Cost after iteration 1096: 0.190151
# Cost after iteration 1097: 0.189965
# Cost after iteration 1098: 0.189786
# Cost after iteration 1099: 0.189613
# Cost after iteration 1100: 0.189446
# Cost after iteration 1101: 0.189285
# Cost after iteration 1102: 0.189130
# Cost after iteration 1103: 0.188981
# Cost after iteration 1104: 0.188836
# Cost after iteration 1105: 0.188697
# Cost after iteration 1106: 0.188562
# Cost after iteration 1107: 0.188432
# Cost after iteration 1108: 0.188306
# Cost after iteration 1109: 0.188184
# Cost after iteration 1110: 0.188066
# Cost after iteration 1111: 0.187952
# Cost after iteration 1112: 0.187842
# Cost after iteration 1113: 0.187735
# Cost after iteration 1114: 0.187632
# Cost after iteration 1115: 0.187532
# Cost after iteration 1116: 0.187435
# Cost after iteration 1117: 0.187341
# Cost after iteration 1118: 0.187249
# Cost after iteration 1119: 0.187161
# Cost after iteration 1120: 0.187075
# Cost after iteration 1121: 0.186992
# Cost after iteration 1122: 0.186911
# Cost after iteration 1123: 0.186832
# Cost after iteration 1124: 0.186756
# Cost after iteration 1125: 0.186682
# Cost after iteration 1126: 0.186610
# Cost after iteration 1127: 0.186540
# Cost after iteration 1128: 0.186472
# Cost after iteration 1129: 0.186406
# Cost after iteration 1130: 0.186342
# Cost after iteration 1131: 0.186279
# Cost after iteration 1132: 0.186218
# Cost after iteration 1133: 0.186159
# Cost after iteration 1134: 0.186101
# Cost after iteration 1135: 0.186045
# Cost after iteration 1136: 0.185990
# Cost after iteration 1137: 0.185936
# Cost after iteration 1138: 0.185884
# Cost after iteration 1139: 0.185833
# Cost after iteration 1140: 0.185784
# Cost after iteration 1141: 0.185735
# Cost after iteration 1142: 0.185688
# Cost after iteration 1143: 0.185642
# Cost after iteration 1144: 0.185597
# Cost after iteration 1145: 0.185553
# Cost after iteration 1146: 0.185510
# Cost after iteration 1147: 0.185468
# Cost after iteration 1148: 0.185427
# Cost after iteration 1149: 0.185387
# Cost after iteration 1150: 0.185347
# Cost after iteration 1151: 0.185309
# Cost after iteration 1152: 0.185271
# Cost after iteration 1153: 0.185234
# Cost after iteration 1154: 0.185198
# Cost after iteration 1155: 0.185163
# Cost after iteration 1156: 0.185128
# Cost after iteration 1157: 0.185094
# Cost after iteration 1158: 0.185061
# Cost after iteration 1159: 0.185028
# Cost after iteration 1160: 0.184997
# Cost after iteration 1161: 0.184965
# Cost after iteration 1162: 0.184934
# Cost after iteration 1163: 0.184904
# Cost after iteration 1164: 0.184875
# Cost after iteration 1165: 0.184846
# Cost after iteration 1166: 0.184818
# Cost after iteration 1167: 0.184791
# Cost after iteration 1168: 0.184765
# Cost after iteration 1169: 0.184740
# Cost after iteration 1170: 0.184719
# Cost after iteration 1171: 0.184701
# Cost after iteration 1172: 0.184691
# Cost after iteration 1173: 0.184695
# Cost after iteration 1174: 0.184722
# Cost after iteration 1175: 0.184794
# Cost after iteration 1176: 0.184943
# Cost after iteration 1177: 0.185253
# Cost after iteration 1178: 0.185826
# Cost after iteration 1179: 0.187002
# Cost after iteration 1180: 0.189095
# Cost after iteration 1181: 0.193684
# Cost after iteration 1182: 0.201701
# Cost after iteration 1183: 0.222607
# Cost after iteration 1184: 0.260922
# Cost after iteration 1185: 0.398532
# Cost after iteration 1186: 0.522668
# Cost after iteration 1187: 1.030679
# Cost after iteration 1188: 0.339917
# Cost after iteration 1189: 0.383362
# Cost after iteration 1190: 0.208851
# Cost after iteration 1191: 0.200646
# Cost after iteration 1192: 0.195768
# Cost after iteration 1193: 0.194241
# Cost after iteration 1194: 0.193447
# Cost after iteration 1195: 0.192955
# Cost after iteration 1196: 0.192563
# Cost after iteration 1197: 0.192215
# Cost after iteration 1198: 0.191892
# Cost after iteration 1199: 0.191586
# Cost after iteration 1200: 0.191296
# Cost after iteration 1201: 0.191018
# Cost after iteration 1202: 0.190754
# Cost after iteration 1203: 0.190501
# Cost after iteration 1204: 0.190259
# Cost after iteration 1205: 0.190028
# Cost after iteration 1206: 0.189807
# Cost after iteration 1207: 0.189595
# Cost after iteration 1208: 0.189393
# Cost after iteration 1209: 0.189199
# Cost after iteration 1210: 0.189014
# Cost after iteration 1211: 0.188836
# Cost after iteration 1212: 0.188666
# Cost after iteration 1213: 0.188503
# Cost after iteration 1214: 0.188347
# Cost after iteration 1215: 0.188197
# Cost after iteration 1216: 0.188053
# Cost after iteration 1217: 0.187915
# Cost after iteration 1218: 0.187783
# Cost after iteration 1219: 0.187656
# Cost after iteration 1220: 0.187533
# Cost after iteration 1221: 0.187416
# Cost after iteration 1222: 0.187303
# Cost after iteration 1223: 0.187194
# Cost after iteration 1224: 0.187089
# Cost after iteration 1225: 0.186989
# Cost after iteration 1226: 0.186892
# Cost after iteration 1227: 0.186798
# Cost after iteration 1228: 0.186708
# Cost after iteration 1229: 0.186621
# Cost after iteration 1230: 0.186537
# Cost after iteration 1231: 0.186456
# Cost after iteration 1232: 0.186378
# Cost after iteration 1233: 0.186303
# Cost after iteration 1234: 0.186230
# Cost after iteration 1235: 0.186159
# Cost after iteration 1236: 0.186091
# Cost after iteration 1237: 0.186025
# Cost after iteration 1238: 0.185961
# Cost after iteration 1239: 0.185899
# Cost after iteration 1240: 0.185839
# Cost after iteration 1241: 0.185781
# Cost after iteration 1242: 0.185724
# Cost after iteration 1243: 0.185669
# Cost after iteration 1244: 0.185616
# Cost after iteration 1245: 0.185565
# Cost after iteration 1246: 0.185515
# Cost after iteration 1247: 0.185466
# Cost after iteration 1248: 0.185419
# Cost after iteration 1249: 0.185373
# Cost after iteration 1250: 0.185328
# Cost after iteration 1251: 0.185284
# Cost after iteration 1252: 0.185242
# Cost after iteration 1253: 0.185201
# Cost after iteration 1254: 0.185160
# Cost after iteration 1255: 0.185121
# Cost after iteration 1256: 0.185083
# Cost after iteration 1257: 0.185046
# Cost after iteration 1258: 0.185009
# Cost after iteration 1259: 0.184974
# Cost after iteration 1260: 0.184939
# Cost after iteration 1261: 0.184905
# Cost after iteration 1262: 0.184872
# Cost after iteration 1263: 0.184840
# Cost after iteration 1264: 0.184808
# Cost after iteration 1265: 0.184777
# Cost after iteration 1266: 0.184747
# Cost after iteration 1267: 0.184717
# Cost after iteration 1268: 0.184688
# Cost after iteration 1269: 0.184660
# Cost after iteration 1270: 0.184632
# Cost after iteration 1271: 0.184605
# Cost after iteration 1272: 0.184578
# Cost after iteration 1273: 0.184552
# Cost after iteration 1274: 0.184526
# Cost after iteration 1275: 0.184501
# Cost after iteration 1276: 0.184476
# Cost after iteration 1277: 0.184452
# Cost after iteration 1278: 0.184428
# Cost after iteration 1279: 0.184405
# Cost after iteration 1280: 0.184382
# Cost after iteration 1281: 0.184359
# Cost after iteration 1282: 0.184338
# Cost after iteration 1283: 0.184317
# Cost after iteration 1284: 0.184296
# Cost after iteration 1285: 0.184277
# Cost after iteration 1286: 0.184260
# Cost after iteration 1287: 0.184246
# Cost after iteration 1288: 0.184237
# Cost after iteration 1289: 0.184238
# Cost after iteration 1290: 0.184254
# Cost after iteration 1291: 0.184300
# Cost after iteration 1292: 0.184398
# Cost after iteration 1293: 0.184596
# Cost after iteration 1294: 0.184962
# Cost after iteration 1295: 0.185691
# Cost after iteration 1296: 0.186977
# Cost after iteration 1297: 0.189654
# Cost after iteration 1298: 0.194263
# Cost after iteration 1299: 0.205099
# Cost after iteration 1300: 0.224025
# Cost after iteration 1301: 0.284569
# Cost after iteration 1302: 0.374946
# Cost after iteration 1303: 0.650099
# Cost after iteration 1304: 0.438514
# Cost after iteration 1305: 0.698206
# Cost after iteration 1306: 0.361693
# Cost after iteration 1307: 0.353641
# Cost after iteration 1308: 0.228338
# Cost after iteration 1309: 0.208840
# Cost after iteration 1310: 0.198283
# Cost after iteration 1311: 0.195081
# Cost after iteration 1312: 0.193561
# Cost after iteration 1313: 0.192858
# Cost after iteration 1314: 0.192387
# Cost after iteration 1315: 0.192024
# Cost after iteration 1316: 0.191705
# Cost after iteration 1317: 0.191411
# Cost after iteration 1318: 0.191134
# Cost after iteration 1319: 0.190870
# Cost after iteration 1320: 0.190618
# Cost after iteration 1321: 0.190376
# Cost after iteration 1322: 0.190144
# Cost after iteration 1323: 0.189922
# Cost after iteration 1324: 0.189708
# Cost after iteration 1325: 0.189503
# Cost after iteration 1326: 0.189306
# Cost after iteration 1327: 0.189117
# Cost after iteration 1328: 0.188936
# Cost after iteration 1329: 0.188761
# Cost after iteration 1330: 0.188593
# Cost after iteration 1331: 0.188432
# Cost after iteration 1332: 0.188277
# Cost after iteration 1333: 0.188128
# Cost after iteration 1334: 0.187985
# Cost after iteration 1335: 0.187847
# Cost after iteration 1336: 0.187715
# Cost after iteration 1337: 0.187587
# Cost after iteration 1338: 0.187464
# Cost after iteration 1339: 0.187346
# Cost after iteration 1340: 0.187232
# Cost after iteration 1341: 0.187122
# Cost after iteration 1342: 0.187016
# Cost after iteration 1343: 0.186914
# Cost after iteration 1344: 0.186816
# Cost after iteration 1345: 0.186721
# Cost after iteration 1346: 0.186630
# Cost after iteration 1347: 0.186541
# Cost after iteration 1348: 0.186456
# Cost after iteration 1349: 0.186374
# Cost after iteration 1350: 0.186294
# Cost after iteration 1351: 0.186217
# Cost after iteration 1352: 0.186143
# Cost after iteration 1353: 0.186071
# Cost after iteration 1354: 0.186002
# Cost after iteration 1355: 0.185935
# Cost after iteration 1356: 0.185870
# Cost after iteration 1357: 0.185807
# Cost after iteration 1358: 0.185746
# Cost after iteration 1359: 0.185687
# Cost after iteration 1360: 0.185630
# Cost after iteration 1361: 0.185574
# Cost after iteration 1362: 0.185520
# Cost after iteration 1363: 0.185468
# ...
# Cost after iteration 2560: 0.186741
# Cost after iteration 2561: 0.187121
# Cost after iteration 2562: 0.187215
# Cost after iteration 2563: 0.187813
# Cost after iteration 2564: 0.187983
# Cost after iteration 2565: 0.188943
# Cost after iteration 2566: 0.189227
# Cost after iteration 2567: 0.190809
# Cost after iteration 2568: 0.191259
# Cost after iteration 2569: 0.193927
# Cost after iteration 2570: 0.194572
# Cost after iteration 2571: 0.199099
# Cost after iteration 2572: 0.199723
# Cost after iteration 2573: 0.207106
# Cost after iteration 2574: 0.206528
# Cost after iteration 2575: 0.217160
# Cost after iteration 2576: 0.212741
# Cost after iteration 2577: 0.224864
# Cost after iteration 2578: 0.215532
# Cost after iteration 2579: 0.225970
# Cost after iteration 2580: 0.215269
# Cost after iteration 2581: 0.222963
# Cost after iteration 2582: 0.214639
# Cost after iteration 2583: 0.220889
# Cost after iteration 2584: 0.215601
# Cost after iteration 2585: 0.222198
# Cost after iteration 2586: 0.219141
# Cost after iteration 2587: 0.227811
# Cost after iteration 2588: 0.225660
# Cost after iteration 2589: 0.237731
# Cost after iteration 2590: 0.233837
# Cost after iteration 2591: 0.248168
# Cost after iteration 2592: 0.238176
# Cost after iteration 2593: 0.248352
# Cost after iteration 2594: 0.231658
# Cost after iteration 2595: 0.231455
# Cost after iteration 2596: 0.215551
# Cost after iteration 2597: 0.209158
# Cost after iteration 2598: 0.199758
# Cost after iteration 2599: 0.195424
# Cost after iteration 2600: 0.191673
# Cost after iteration 2601: 0.190076
# Cost after iteration 2602: 0.188761
# Cost after iteration 2603: 0.188180
# Cost after iteration 2604: 0.187623
# Cost after iteration 2605: 0.187347
# Cost after iteration 2606: 0.187049
# Cost after iteration 2607: 0.186882
# Cost after iteration 2608: 0.186693
# Cost after iteration 2609: 0.186573
# Cost after iteration 2610: 0.186440
# Cost after iteration 2611: 0.186346
# Cost after iteration 2612: 0.186243
# Cost after iteration 2613: 0.186166
# Cost after iteration 2614: 0.186083
# Cost after iteration 2615: 0.186017
# Cost after iteration 2616: 0.185946
# Cost after iteration 2617: 0.185890
# Cost after iteration 2618: 0.185828
# Cost after iteration 2619: 0.185779
# Cost after iteration 2620: 0.185725
# Cost after iteration 2621: 0.185681
# Cost after iteration 2622: 0.185634
# Cost after iteration 2623: 0.185597
# Cost after iteration 2624: 0.185556
# Cost after iteration 2625: 0.185525
# Cost after iteration 2626: 0.185490
# Cost after iteration 2627: 0.185467
# Cost after iteration 2628: 0.185438
# Cost after iteration 2629: 0.185425
# Cost after iteration 2630: 0.185405
# Cost after iteration 2631: 0.185406
# Cost after iteration 2632: 0.185397
# Cost after iteration 2633: 0.185418
# Cost after iteration 2634: 0.185425
# Cost after iteration 2635: 0.185478
# Cost after iteration 2636: 0.185511
# Cost after iteration 2637: 0.185618
# Cost after iteration 2638: 0.185690
# Cost after iteration 2639: 0.185893
# Cost after iteration 2640: 0.186030
# Cost after iteration 2641: 0.186409
# Cost after iteration 2642: 0.186657
# Cost after iteration 2643: 0.187377
# Cost after iteration 2644: 0.187821
# Cost after iteration 2645: 0.189225
# Cost after iteration 2646: 0.190023
# Cost after iteration 2647: 0.192857
# Cost after iteration 2648: 0.194267
# Cost after iteration 2649: 0.200092
# Cost after iteration 2650: 0.202081
# Cost after iteration 2651: 0.213473
# Cost after iteration 2652: 0.213135
# Cost after iteration 2653: 0.231245
# Cost after iteration 2654: 0.220664
# Cost after iteration 2655: 0.239176
# Cost after iteration 2656: 0.218999
# Cost after iteration 2657: 0.230088
# Cost after iteration 2658: 0.212671
# Cost after iteration 2659: 0.217659
# Cost after iteration 2660: 0.207557
# Cost after iteration 2661: 0.210065
# Cost after iteration 2662: 0.204529
# Cost after iteration 2663: 0.206333
# Cost after iteration 2664: 0.203289
# Cost after iteration 2665: 0.205183
# Cost after iteration 2666: 0.203448
# Cost after iteration 2667: 0.205739
# Cost after iteration 2668: 0.204494
# Cost after iteration 2669: 0.207148
# Cost after iteration 2670: 0.205769
# Cost after iteration 2671: 0.208467
# Cost after iteration 2672: 0.206494
# Cost after iteration 2673: 0.208680
# Cost after iteration 2674: 0.205888
# Cost after iteration 2675: 0.206964
# Cost after iteration 2676: 0.203512
# Cost after iteration 2677: 0.203258
# Cost after iteration 2678: 0.199709
# Cost after iteration 2679: 0.198559
# Cost after iteration 2680: 0.195571
# Cost after iteration 2681: 0.194265
# Cost after iteration 2682: 0.192157
# Cost after iteration 2683: 0.191142
# Cost after iteration 2684: 0.189819
# Cost after iteration 2685: 0.189159
# Cost after iteration 2686: 0.188363
# Cost after iteration 2687: 0.187965
# Cost after iteration 2688: 0.187480
# Cost after iteration 2689: 0.187246
# Cost after iteration 2690: 0.186936
# Cost after iteration 2691: 0.186801
# Cost after iteration 2692: 0.186592
# Cost after iteration 2693: 0.186519
# Cost after iteration 2694: 0.186372
# Cost after iteration 2695: 0.186342
# Cost after iteration 2696: 0.186235
# Cost after iteration 2697: 0.186241
# Cost after iteration 2698: 0.186164
# Cost after iteration 2699: 0.186204
# Cost after iteration 2700: 0.186152
# Cost after iteration 2701: 0.186233
# Cost after iteration 2702: 0.186206
# Cost after iteration 2703: 0.186341
# Cost after iteration 2704: 0.186341
# Cost after iteration 2705: 0.186553
# Cost after iteration 2706: 0.186589
# Cost after iteration 2707: 0.186920
# Cost after iteration 2708: 0.187003
# Cost after iteration 2709: 0.187523
# Cost after iteration 2710: 0.187677
# Cost after iteration 2711: 0.188512
# Cost after iteration 2712: 0.188772
# Cost after iteration 2713: 0.190147
# Cost after iteration 2714: 0.190564
# Cost after iteration 2715: 0.192887
# Cost after iteration 2716: 0.193514
# Cost after iteration 2717: 0.197492
# Cost after iteration 2718: 0.198229
# Cost after iteration 2719: 0.204879
# Cost after iteration 2720: 0.204876
# Cost after iteration 2721: 0.214942
# Cost after iteration 2722: 0.211727
# Cost after iteration 2723: 0.224063
# Cost after iteration 2724: 0.215559
# Cost after iteration 2725: 0.226874
# Cost after iteration 2726: 0.215763
# Cost after iteration 2727: 0.224181
# Cost after iteration 2728: 0.214921
# Cost after iteration 2729: 0.221419
# Cost after iteration 2730: 0.215375
# Cost after iteration 2731: 0.221801
# Cost after iteration 2732: 0.218290
# Cost after iteration 2733: 0.226440
# Cost after iteration 2734: 0.224228
# Cost after iteration 2735: 0.235651
# Cost after iteration 2736: 0.232426
# Cost after iteration 2737: 0.246805
# Cost after iteration 2738: 0.238288
# Cost after iteration 2739: 0.250181
# Cost after iteration 2740: 0.234221
# Cost after iteration 2741: 0.236219
# Cost after iteration 2742: 0.219280
# Cost after iteration 2743: 0.213285
# Cost after iteration 2744: 0.202390
# Cost after iteration 2745: 0.197308
# Cost after iteration 2746: 0.192686
# Cost after iteration 2747: 0.190699
# Cost after iteration 2748: 0.189103
# Cost after iteration 2749: 0.188405
# Cost after iteration 2750: 0.187765
# Cost after iteration 2751: 0.187455
# Cost after iteration 2752: 0.187127
# Cost after iteration 2753: 0.186946
# Cost after iteration 2754: 0.186745
# Cost after iteration 2755: 0.186619
# Cost after iteration 2756: 0.186479
# Cost after iteration 2757: 0.186382
# Cost after iteration 2758: 0.186276
# Cost after iteration 2759: 0.186197
# Cost after iteration 2760: 0.186111
# Cost after iteration 2761: 0.186043
# Cost after iteration 2762: 0.185971
# Cost after iteration 2763: 0.185912
# Cost after iteration 2764: 0.185850
# Cost after iteration 2765: 0.185799
# Cost after iteration 2766: 0.185744
# Cost after iteration 2767: 0.185699
# Cost after iteration 2768: 0.185650
# Cost after iteration 2769: 0.185611
# Cost after iteration 2770: 0.185569
# Cost after iteration 2771: 0.185536
# Cost after iteration 2772: 0.185499
# Cost after iteration 2773: 0.185473
# Cost after iteration 2774: 0.185443
# Cost after iteration 2775: 0.185425
# Cost after iteration 2776: 0.185402
# Cost after iteration 2777: 0.185397
# Cost after iteration 2778: 0.185384
# Cost after iteration 2779: 0.185395
# Cost after iteration 2780: 0.185396
# Cost after iteration 2781: 0.185435
# Cost after iteration 2782: 0.185457
# Cost after iteration 2783: 0.185539
# Cost after iteration 2784: 0.185594
# Cost after iteration 2785: 0.185753
# Cost after iteration 2786: 0.185862
# Cost after iteration 2787: 0.186161
# Cost after iteration 2788: 0.186361
# Cost after iteration 2789: 0.186925
# Cost after iteration 2790: 0.187286
# Cost after iteration 2791: 0.188378
# Cost after iteration 2792: 0.189027
# Cost after iteration 2793: 0.191213
# Cost after iteration 2794: 0.192381
# Cost after iteration 2795: 0.196883
# Cost after iteration 2796: 0.198780
# Cost after iteration 2797: 0.207905
# Cost after iteration 2798: 0.209182
# Cost after iteration 2799: 0.225281
# Cost after iteration 2800: 0.219130
# Cost after iteration 2801: 0.238929
# Cost after iteration 2802: 0.220744
# Cost after iteration 2803: 0.234922
# Cost after iteration 2804: 0.215011
# Cost after iteration 2805: 0.221667
# Cost after iteration 2806: 0.209092
# Cost after iteration 2807: 0.212158
# Cost after iteration 2808: 0.205284
# Cost after iteration 2809: 0.207162
# Cost after iteration 2810: 0.203388
# Cost after iteration 2811: 0.205130
# Cost after iteration 2812: 0.203029
# Cost after iteration 2813: 0.205081
# Cost after iteration 2814: 0.203734
# Cost after iteration 2815: 0.206166
# Cost after iteration 2816: 0.204899
# Cost after iteration 2817: 0.207489
# Cost after iteration 2818: 0.205799
# Cost after iteration 2819: 0.208087
# Cost after iteration 2820: 0.205674
# Cost after iteration 2821: 0.207088
# Cost after iteration 2822: 0.203966
# Cost after iteration 2823: 0.204146
# Cost after iteration 2824: 0.200723
# Cost after iteration 2825: 0.199866
# Cost after iteration 2826: 0.196767
# Cost after iteration 2827: 0.195518
# Cost after iteration 2828: 0.193179
# Cost after iteration 2829: 0.192086
# Cost after iteration 2830: 0.190546
# Cost after iteration 2831: 0.189787
# Cost after iteration 2832: 0.188839
# Cost after iteration 2833: 0.188364
# Cost after iteration 2834: 0.187785
# Cost after iteration 2835: 0.187500
# Cost after iteration 2836: 0.187134
# Cost after iteration 2837: 0.186967
# Cost after iteration 2838: 0.186725
# Cost after iteration 2839: 0.186631
# Cost after iteration 2840: 0.186463
# Cost after iteration 2841: 0.186418
# Cost after iteration 2842: 0.186297
# Cost after iteration 2843: 0.186291
# Cost after iteration 2844: 0.186204
# Cost after iteration 2845: 0.186233
# Cost after iteration 2846: 0.186173
# Cost after iteration 2847: 0.186241
# Cost after iteration 2848: 0.186205
# Cost after iteration 2849: 0.186323
# Cost after iteration 2850: 0.186315
# Cost after iteration 2851: 0.186503
# Cost after iteration 2852: 0.186527
# Cost after iteration 2853: 0.186820
# Cost after iteration 2854: 0.186889
# Cost after iteration 2855: 0.187347
# Cost after iteration 2856: 0.187478
# Cost after iteration 2857: 0.188208
# Cost after iteration 2858: 0.188433
# Cost after iteration 2859: 0.189624
# Cost after iteration 2860: 0.189990
# Cost after iteration 2861: 0.191986
# Cost after iteration 2862: 0.192550
# Cost after iteration 2863: 0.195957
# Cost after iteration 2864: 0.196697
# Cost after iteration 2865: 0.202458
# Cost after iteration 2866: 0.202845
# Cost after iteration 2867: 0.211904
# Cost after iteration 2868: 0.209967
# Cost after iteration 2869: 0.221913
# Cost after iteration 2870: 0.214966
# Cost after iteration 2871: 0.226922
# Cost after iteration 2872: 0.216122
# Cost after iteration 2873: 0.225437
# Cost after iteration 2874: 0.215396
# Cost after iteration 2875: 0.222377
# Cost after iteration 2876: 0.215453
# Cost after iteration 2877: 0.221881
# Cost after iteration 2878: 0.217743
# Cost after iteration 2879: 0.225469
# Cost after iteration 2880: 0.222987
# Cost after iteration 2881: 0.233694
# Cost after iteration 2882: 0.230872
# Cost after iteration 2883: 0.244909
# Cost after iteration 2884: 0.237789
# Cost after iteration 2885: 0.250916
# Cost after iteration 2886: 0.236171
# Cost after iteration 2887: 0.240483
# Cost after iteration 2888: 0.222936
# Cost after iteration 2889: 0.217850
# Cost after iteration 2890: 0.205458
# Cost after iteration 2891: 0.199694
# Cost after iteration 2892: 0.194015
# Cost after iteration 2893: 0.191539
# Cost after iteration 2894: 0.189558
# Cost after iteration 2895: 0.188702
# Cost after iteration 2896: 0.187947
# Cost after iteration 2897: 0.187588
# Cost after iteration 2898: 0.187221
# Cost after iteration 2899: 0.187022
# Cost after iteration 2900: 0.186804
# Cost after iteration 2901: 0.186670
# Cost after iteration 2902: 0.186522
# Cost after iteration 2903: 0.186420
# Cost after iteration 2904: 0.186309
# Cost after iteration 2905: 0.186227
# Cost after iteration 2906: 0.186139
# Cost after iteration 2907: 0.186069
# Cost after iteration 2908: 0.185995
# Cost after iteration 2909: 0.185935
# Cost after iteration 2910: 0.185871
# Cost after iteration 2911: 0.185818
# Cost after iteration 2912: 0.185762
# Cost after iteration 2913: 0.185715
# Cost after iteration 2914: 0.185665
# Cost after iteration 2915: 0.185625
# Cost after iteration 2916: 0.185581
# Cost after iteration 2917: 0.185546
# Cost after iteration 2918: 0.185507
# Cost after iteration 2919: 0.185479
# Cost after iteration 2920: 0.185446
# Cost after iteration 2921: 0.185425
# Cost after iteration 2922: 0.185400
# Cost after iteration 2923: 0.185389
# Cost after iteration 2924: 0.185372
# Cost after iteration 2925: 0.185376
# Cost after iteration 2926: 0.185371
# Cost after iteration 2927: 0.185396
# Cost after iteration 2928: 0.185409
# Cost after iteration 2929: 0.185470
# Cost after iteration 2930: 0.185510
# Cost after iteration 2931: 0.185632
# Cost after iteration 2932: 0.185716
# Cost after iteration 2933: 0.185947
# Cost after iteration 2934: 0.186106
# Cost after iteration 2935: 0.186541
# Cost after iteration 2936: 0.186829
# Cost after iteration 2937: 0.187664
# Cost after iteration 2938: 0.188183
# Cost after iteration 2939: 0.189840
# Cost after iteration 2940: 0.190780
# Cost after iteration 2941: 0.194176
# Cost after iteration 2942: 0.195817
# Cost after iteration 2943: 0.202842
# Cost after iteration 2944: 0.204841
# Cost after iteration 2945: 0.218262
# Cost after iteration 2946: 0.216125
# Cost after iteration 2947: 0.235753
# Cost after iteration 2948: 0.221561
# Cost after iteration 2949: 0.238965
# Cost after iteration 2950: 0.217739
# Cost after iteration 2951: 0.226926
# Cost after iteration 2952: 0.211220
# Cost after iteration 2953: 0.215270
# Cost after iteration 2954: 0.206584
# Cost after iteration 2955: 0.208759
# Cost after iteration 2956: 0.204026
# Cost after iteration 2957: 0.205774
# Cost after iteration 2958: 0.203174
# Cost after iteration 2959: 0.205132
# Cost after iteration 2960: 0.203593
# Cost after iteration 2961: 0.205956
# Cost after iteration 2962: 0.204713
# Cost after iteration 2963: 0.207354
# Cost after iteration 2964: 0.205832
# Cost after iteration 2965: 0.208352
# Cost after iteration 2966: 0.206157
# Cost after iteration 2967: 0.207974
# Cost after iteration 2968: 0.204994
# Cost after iteration 2969: 0.205605
# Cost after iteration 2970: 0.202132
# Cost after iteration 2971: 0.201528
# Cost after iteration 2972: 0.198180
# Cost after iteration 2973: 0.196939
# Cost after iteration 2974: 0.194279
# Cost after iteration 2975: 0.193065
# Cost after iteration 2976: 0.191262
# Cost after iteration 2977: 0.190377
# Cost after iteration 2978: 0.189261
# Cost after iteration 2979: 0.188699
# Cost after iteration 2980: 0.188025
# Cost after iteration 2981: 0.187686
# Cost after iteration 2982: 0.187269
# Cost after iteration 2983: 0.187068
# Cost after iteration 2984: 0.186797
# Cost after iteration 2985: 0.186681
# Cost after iteration 2986: 0.186496
# Cost after iteration 2987: 0.186434
# Cost after iteration 2988: 0.186303
# Cost after iteration 2989: 0.186280
# Cost after iteration 2990: 0.186185
# Cost after iteration 2991: 0.186197
# Cost after iteration 2992: 0.186129
# Cost after iteration 2993: 0.186175
# Cost after iteration 2994: 0.186132
# Cost after iteration 2995: 0.186220
# Cost after iteration 2996: 0.186201
# Cost after iteration 2997: 0.186347
# Cost after iteration 2998: 0.186357
# Cost after iteration 2999: 0.186587
# W1 = [[-1.86262457  1.60745666]
#  [-2.0367822   1.80986553]]
# b1 = [[ 4.46979068]
#  [-5.7523073 ]]
# W2 = [[ 7.48732348 -7.3716039 ]]
# b2 = [[-3.67676775]]

# %% [markdown]
# ##### __Expected Output__
# Note: the actual values can be different!
#
# ```Python
# Cost after iteration 0: 0.693148
# Cost after iteration 1: 0.693147
# Cost after iteration 2: 0.693147
# Cost after iteration 3: 0.693147
# Cost after iteration 4: 0.693147
# Cost after iteration 5: 0.693147
# ...
# Cost after iteration 2995: 0.209524
# Cost after iteration 2996: 0.208025
# Cost after iteration 2997: 0.210427
# Cost after iteration 2998: 0.208929
# Cost after iteration 2999: 0.211306
# W1 = [[ 2.14274251 -1.93155541]
#  [ 2.20268789 -2.1131799 ]]
# b1 = [[-4.83079243]
#  [ 6.2845223 ]]
# W2 = [[-7.21370685  7.0898022 ]]
# b2 = [[-3.48755239]]
# ```

# %%
# Note: 
# Actual values are not checked here in the unit tests (due to random initialization).
w3_unittest.test_nn_model(nn_model)
# Out:
#  All tests passed

# %% [markdown]
# The final model parameters can be used to find the boundary line and for making predictions.

# %% [markdown]
# <a name='ex08'></a>
# ### Exercise 8
#
# Computes probabilities using forward propagation, and make classification to 0/1 using 0.5 as the threshold.

# %%
# GRADED FUNCTION: predict

def predict(X, parameters):
    """
    Using the learned parameters, predicts a class for each example in X
    
    Arguments:
    parameters -- python dictionary containing your parameters 
    X -- input data of size (n_x, m)
    
    Returns
    predictions -- vector of predictions of our model (blue: 0 / red: 1)
    """
    
    ### START CODE HERE ### (в‰€ 2 lines of code)
    A2, cache = forward_propagation(X, parameters)
    predictions = A2 > 0.5
    ### END CODE HERE ###
    
    return predictions

# %%
X_pred = np.array([[2, 8, 2, 8], [2, 8, 8, 2]])
Y_pred = predict(X_pred, parameters)

print(f"Coordinates (in the columns):\n{X_pred}")
print(f"Predictions:\n{Y_pred}")
# Out:
# Coordinates (in the columns):
# [[2 8 2 8]
#  [2 8 8 2]]
# Predictions:
# [[ True  True False False]]

# %% [markdown]
# ##### __Expected Output__
#
# ```Python
# Coordinates (in the columns):
# [[2 8 2 8]
#  [2 8 8 2]]
# Predictions:
# [[ True  True False False]]
# ```

# %%
w3_unittest.test_predict(predict)
# Out:
#  All tests passed

# %% [markdown]
# Let's visualize the boundary line. Do not worry if you don't understand the function `plot_decision_boundary` line by line - it simply makes prediction for some points on the plane and plots them as a contour plot (just two colors - blue and red).

# %%
def plot_decision_boundary(predict, parameters, X, Y):
    # Define bounds of the domain.
    min1, max1 = X[0, :].min()-1, X[0, :].max()+1
    min2, max2 = X[1, :].min()-1, X[1, :].max()+1
    # Define the x and y scale.
    x1grid = np.arange(min1, max1, 0.1)
    x2grid = np.arange(min2, max2, 0.1)
    # Create all of the lines and rows of the grid.
    xx, yy = np.meshgrid(x1grid, x2grid)
    # Flatten each grid to a vector.
    r1, r2 = xx.flatten(), yy.flatten()
    r1, r2 = r1.reshape((1, len(r1))), r2.reshape((1, len(r2)))
    # Vertical stack vectors to create x1,x2 input for the model.
    grid = np.vstack((r1,r2))
    # Make predictions for the grid.
    predictions = predict(grid, parameters)
    # Reshape the predictions back into a grid.
    zz = predictions.reshape(xx.shape)
    # Plot the grid of x, y and z values as a surface.
    plt.contourf(xx, yy, zz, cmap=plt.cm.Spectral.reversed())
    plt.scatter(X[0, :], X[1, :], c=Y, cmap=colors.ListedColormap(['blue', 'red']));

# Plot the decision boundary.
plot_decision_boundary(predict, parameters, X, Y)
plt.title("Decision Boundary for hidden layer size " + str(n_h))
# Out:
# Text(0.5, 1.0, 'Decision Boundary for hidden layer size 2')

# %% [markdown]
# That's great, you can see that more complicated classification problems can be solved with two layer neural network!

# %% [markdown]
# <a name='4'></a>
# ## 4 - Optional: Other Dataset

# %% [markdown]
# Build a slightly different dataset:

# %%
n_samples = 2000
samples, labels = make_blobs(n_samples=n_samples, 
                             centers=([2.5, 3], [6.7, 7.9], [2.1, 7.9], [7.4, 2.8]), 
                             cluster_std=1.1,
                             random_state=0)
labels[(labels == 0)] = 0
labels[(labels == 1)] = 1
labels[(labels == 2) | (labels == 3)] = 1
X_2 = np.transpose(samples)
Y_2 = labels.reshape((1,n_samples))

plt.scatter(X_2[0, :], X_2[1, :], c=Y_2, cmap=colors.ListedColormap(['blue', 'red']));

# %% [markdown]
# Notice that when building your neural network, a number of the nodes in the hidden layer could be taken as a parameter. Try to change this parameter and investigate the results:

# %%
# parameters_2 = nn_model(X_2, Y_2, n_h=1, num_iterations=3000, learning_rate=1.2, print_cost=False)
# parameters_2 = nn_model(X_2, Y_2, n_h=2, num_iterations=3000, learning_rate=1.2, print_cost=False)
parameters_2 = nn_model(X_2, Y_2, n_h=15, num_iterations=3000, learning_rate=1.2, print_cost=False)

# This function will call predict function 
plot_decision_boundary(predict, parameters_2, X_2, Y_2)
plt.title("Decision Boundary for hidden layer size " + str(n_h))
# Out:
# Text(0.5, 1.0, 'Decision Boundary for hidden layer size 2')

# %% [markdown]
# You can see that there are some misclassified points - real-world datasets are usually linearly inseparable, and there will be a small percentage of errors. More than that, you do not want to build a model that fits too closely, almost exactly to a particular set of data - it may fail to predict future observations. This problem is known as **overfitting**.

# %% [markdown]
# Congrats on finishing this programming assignment!
